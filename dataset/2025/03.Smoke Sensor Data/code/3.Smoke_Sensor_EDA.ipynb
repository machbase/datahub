# %% [markdown]
# # Smoke Sensor Data Exploratory Data Analysis

# %% [markdown]
# ## Import Necessary Libraries

# %%
## Import necessary libraries
from urllib.parse import quote

## Import necessary API
import sys
sys.path.append('../../../../')
from api.v2.util.data_load import data_load
from api.v2.util.get_tag_name import show_column
from api.v2.eda.Data_Info import Data_Info
from api.v2.eda.Statistical_test import adf_test, kpss_test, pp_test, ljung_box_test, arch_test, vif_test
from api.v2.eda.Visualize_EDA import Visualize_EDA

# %% [markdown]
# ## Set Smoke Sensor Data Base Parameter

# %%
# Set Smoke Sensor Data Base Parameter

# Set MachBase Neo URL address
URL = 'http://127.0.0.1:5654'
# Set Tag Table Name
table = 'smoke'
# Set TimeFormat - > 'default' or '2006-01-02 15:04:05.000000'(Divided down to the nanosecond)
timeformat = 'Default'
# Set resample Option -> D(day), H(hour), T(minute), S(second)
resample_freq = None

# %% [markdown]
# ## Check Smoke Sensor Data Info

# %%
# Print Smoke Sensor DataInfo
Data_Info(URL, table, timeformat, resample_freq)
# Out:
# Tag List: ['CNT', 'Fire Alarm', 'Humidity[%]', 'NC0.5', 'NC1.0', 'NC2.5', 'PM1.0', 'PM2.5', 'Pressure[hPa]', 'Raw Ethanol', 'Raw H2', 'TVOC[ppb]', 'Temperature[C]', 'eCO2[ppm]']
# --------------------------------------------
# Number of data: 62630
# --------------------------------------------
# Start Time: 2025-01-16 00:00:00
# End Time: 2025-01-16 17:23:49
# --------------------------------------------
# Missing Values: 0
# --------------------------------------------
# Smallest time interval: 1.00 seconds
# Largest time interval: 1.00 seconds
# --------------------------------------------
# Maximum sampling rate (per second): 1.0 Hz
# --------------------------------------------

# %% [markdown]
# ## Set Smoke Sensor Data Extra Parmeter
# * Set based on the information confirmed in the previous step

# %%
# Set the desired tag names
tags = show_column(URL, table)
# Wrap each item in the list with single quotes and separate with commas
tags_ = ",".join(f"'{tag}'" for tag in tags)
# Set Tag Name
name = quote(tags_, safe=":/")
# Set Start time
start_time = '2025-01-16 00:00:00'
# Set End time 
end_time = '2025-01-16 17:23:49'
# Set TimeFormat - > 'default' or quote('2006-01-02 15:04:05.000000')(Divided down to the nanosecond)
timeformat = 'default'

# %%
# Smoke Sensor Data Load
df = data_load(URL, table, name, start_time, end_time, timeformat, resample_freq)

# %%
df
# Out:
# NAME                    CNT  Fire Alarm  Humidity[%]  NC0.5  NC1.0  NC2.5  \
# TIME
# 2025-01-16 00:00:00     0.0         0.0        57.36   0.00  0.000  0.000
# 2025-01-16 00:00:01     1.0         0.0        56.67   0.00  0.000  0.000
# 2025-01-16 00:00:02     2.0         0.0        55.96   0.00  0.000  0.000
# 2025-01-16 00:00:03     3.0         0.0        55.28   0.00  0.000  0.000
# 2025-01-16 00:00:04     4.0         0.0        54.69   0.00  0.000  0.000
# ...                     ...         ...          ...    ...    ...    ...
# 2025-01-16 17:23:45  5739.0         0.0        15.79   4.32  0.673  0.015
# 2025-01-16 17:23:46  5740.0         0.0        15.87   4.18  0.652  0.015
# 2025-01-16 17:23:47  5741.0         0.0        15.84   3.95  0.617  0.014
# 2025-01-16 17:23:48  5742.0         0.0        16.04   3.92  0.611  0.014
# 2025-01-16 17:23:49  5743.0         0.0        16.52   3.90  0.607  0.014
#
# NAME                 PM1.0  PM2.5  Pressure[hPa]  Raw Ethanol   Raw H2  \
# TIME
# 2025-01-16 00:00:00   0.00   0.00        939.735      18520.0  12306.0
# 2025-01-16 00:00:01   0.00   0.00        939.744      18651.0  12345.0
# 2025-01-16 00:00:02   0.00   0.00        939.738      18764.0  12374.0
# 2025-01-16 00:00:03   0.00   0.00        939.736      18849.0  12390.0
# 2025-01-16 00:00:04   0.00   0.00        939.744      18921.0  12403.0
# ...                    ...    ...            ...          ...      ...
# 2025-01-16 17:23:45   0.63   0.65        936.670      20569.0  13723.0
# 2025-01-16 17:23:46   0.61   0.63        936.678      20588.0  13731.0
# 2025-01-16 17:23:47   0.57   0.60        936.687      20582.0  13725.0
# 2025-01-16 17:23:48   0.57   0.59        936.680      20566.0  13712.0
# 2025-01-16 17:23:49   0.57   0.59        936.676      20543.0  13696.0
#
# NAME                 TVOC[ppb]  Temperature[C]  eCO2[ppm]
# TIME
# 2025-01-16 00:00:00        0.0          20.000      400.0
# 2025-01-16 00:00:01        0.0          20.015      400.0
# 2025-01-16 00:00:02        0.0          20.029      400.0
# 2025-01-16 00:00:03        0.0          20.044      400.0
# 2025-01-16 00:00:04        0.0          20.059      400.0
# ...                        ...             ...        ...
# 2025-01-16 17:23:45      625.0          18.438      400.0
# 2025-01-16 17:23:46      612.0          18.653      400.0
# 2025-01-16 17:23:47      627.0          18.867      400.0
# 2025-01-16 17:23:48      638.0          19.083      400.0
# 2025-01-16 17:23:49      643.0          19.299      400.0
#
# [62630 rows x 14 columns]

# %% [markdown]
# ## Check Visualize_EDA

# %%
# Adjust period based on data for Decomposition
period = 24
# Plot width 
x_size = 10
# Plot height
y_size = 10
# Set option
# 1.HeatMap, 2.plot, 3.Decomposition, 4.All 
option = 4

# Set Start Function
Visualize_EDA(df, period, x_size, y_size, option)
# Out:
# Start Visualize All Method
# Removed NaN Columns: set()
# Save Finish

# %% [markdown]
# ## Check Statistical_Test

# %%
# Check ADF Test
adf_test(df)
# Out:
# adf_test for column: CNT
# ADF Statistic: -2.519067678620451
# p-value: 0.11090361221281575
# Critical Values: {'1%': -3.4304544175708225, '5%': -2.861586150626941, '10%': -2.566794564416667}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: Fire Alarm
# ADF Statistic: -2.2779698978326657
# p-value: 0.17917157900477515
# Critical Values: {'1%': -3.4304544843057783, '5%': -2.861586180122033, '10%': -2.5667945801159964}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: Humidity[%]
# ADF Statistic: -4.5619567415607944
# p-value: 0.00015171222389763763
# Critical Values: {'1%': -3.430454517705255, '5%': -2.8615861948837207, '10%': -2.5667945879731886}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: NC0.5
# ADF Statistic: -9.4610743414588
# p-value: 4.352300630761816e-16
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: NC1.0
# ADF Statistic: -12.12114938624509
# p-value: 1.8240555082220074e-22
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: NC2.5
# ADF Statistic: -14.463496899033336
# p-value: 6.786336803376487e-27
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: PM1.0
# ADF Statistic: -10.189231406751283
# p-value: 6.387089311182377e-18
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: PM2.5
# ADF Statistic: -11.944640300004094
# p-value: 4.4597548206652465e-22
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: Pressure[hPa]
# ADF Statistic: -3.8489450298676458
# p-value: 0.0024444214428856587
# Critical Values: {'1%': -3.4304544175708225, '5%': -2.861586150626941, '10%': -2.566794564416667}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: Raw Ethanol
# ADF Statistic: -6.744543502981222
# p-value: 3.058584660214495e-09
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: Raw H2
# ADF Statistic: -7.4191016986185
# p-value: 6.810758332051466e-11
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: TVOC[ppb]
# ADF Statistic: -8.610737513519343
# p-value: 6.486376609319198e-14
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: Temperature[C]
# ADF Statistic: -2.3238145662881857
# p-value: 0.16440228540423368
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# adf_test for column: eCO2[ppm]
# ADF Statistic: -10.110731102824422
# p-value: 1.001966019706179e-17
# Critical Values: {'1%': -3.430454519375789, '5%': -2.861586195622053, '10%': -2.56679458836618}
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------

# %%
# Check KPSS Test
kpss_test(df)
# Out:
# kpss_test for column: CNT
# KPSS Statistic: 3.216313032595036
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: Fire Alarm
# KPSS Statistic: 8.863089448553268
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: Humidity[%]
# KPSS Statistic: 12.804941514042497
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: NC0.5
# KPSS Statistic: 1.569818121678183
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: NC1.0
# KPSS Statistic: 1.186959582272469
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: NC2.5
# KPSS Statistic: 0.9094094467862632
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: PM1.0
# KPSS Statistic: 1.4364764347585444
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: PM2.5
# KPSS Statistic: 1.2081824431227168
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: Pressure[hPa]
# KPSS Statistic: 15.668567548360127
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: Raw Ethanol
# KPSS Statistic: 1.3497115668355122
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: Raw H2
# KPSS Statistic: 2.8181329488578815
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: TVOC[ppb]
# KPSS Statistic: 3.0471627471517673
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: Temperature[C]
# KPSS Statistic: 10.844348323602256
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# kpss_test for column: eCO2[ppm]
# KPSS Statistic: 1.7651935925408975
# p-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------

# %%
# Check PP Test
pp_test(df)
# Out:
# pp_test for column: CNT
#
# Phillips-Perron Test for column: CNT
# Test Statistic: -2.5222625570384536
# p-value: 0.11015113633069135
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: Fire Alarm
#
# Phillips-Perron Test for column: Fire Alarm
# Test Statistic: -2.5372393443775443
# p-value: 0.10667445140613785
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: Humidity[%]
#
# Phillips-Perron Test for column: Humidity[%]
# Test Statistic: -4.0730784344058275
# p-value: 0.0010726644532566974
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: NC0.5
#
# Phillips-Perron Test for column: NC0.5
# Test Statistic: -14.001112762295815
# p-value: 3.8605601405508744e-26
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: NC1.0
#
# Phillips-Perron Test for column: NC1.0
# Test Statistic: -16.237050744079298
# p-value: 3.760555298037193e-29
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: NC2.5
#
# Phillips-Perron Test for column: NC2.5
# Test Statistic: -18.073054054273058
# p-value: 2.600601104993462e-30
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: PM1.0
#
# Phillips-Perron Test for column: PM1.0
# Test Statistic: -14.196844748663159
# p-value: 1.8162586541099099e-26
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: PM2.5
#
# Phillips-Perron Test for column: PM2.5
# Test Statistic: -16.07538477301288
# p-value: 5.450307516627168e-29
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: Pressure[hPa]
#
# Phillips-Perron Test for column: Pressure[hPa]
# Test Statistic: -3.8051791656264218
# p-value: 0.0028547676392186193
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: Raw Ethanol
#
# Phillips-Perron Test for column: Raw Ethanol
# Test Statistic: -5.820657279062708
# p-value: 4.1905883017530944e-07
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: Raw H2
#
# Phillips-Perron Test for column: Raw H2
# Test Statistic: -8.531635327910177
# p-value: 1.0338983605244511e-13
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: TVOC[ppb]
#
# Phillips-Perron Test for column: TVOC[ppb]
# Test Statistic: -7.590423862784303
# p-value: 2.5400672991181907e-11
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: Temperature[C]
#
# Phillips-Perron Test for column: Temperature[C]
# Test Statistic: -1.520277711547723
# p-value: 0.5234574639019303
# The series is not stationary
# ------------------------------------------------------------------------------------------------------------------
#
# pp_test for column: eCO2[ppm]
#
# Phillips-Perron Test for column: eCO2[ppm]
# Test Statistic: -31.612870366280422
# p-value: 0.0
# The series is stationary
# ------------------------------------------------------------------------------------------------------------------

# %%
# Check ljung box Test
ljung_box_test(df, lags=10)
# Out:
# Ljung-Box Test for column: CNT
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: Fire Alarm
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: Humidity[%]
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: NC0.5
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: NC1.0
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: NC2.5
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: PM1.0
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: PM2.5
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: Pressure[hPa]
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: Raw Ethanol
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: Raw H2
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: TVOC[ppb]
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: Temperature[C]
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------
#
# Ljung-Box Test for column: eCO2[ppm]
# p-value: 0.0
# There is autocorrelation
# ------------------------------------------------------------------------------------------------------------------

# %%
# Check Arch Test
arch_test(df)
# Out:
# arch_test for column: CNT
# ARCH Model Results:
#
# Omega (Intercept): 5.77e+06
# Alpha[1] (ARCH Term): 0.8247
#
# Model Evaluation:
# Log-Likelihood: -626709.71
# AIC (Akaike Information Criterion): 1253425.43
# BIC (Bayesian Information Criterion): 1253452.56
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: Fire Alarm
# ARCH Model Results:
#
# Omega (Intercept): 5.83e-02
# Alpha[1] (ARCH Term): 0.8639
#
# Model Evaluation:
# Log-Likelihood: -26560.45
# AIC (Akaike Information Criterion): 53126.90
# BIC (Bayesian Information Criterion): 53154.04
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: Humidity[%]
# ARCH Model Results:
#
# Omega (Intercept): 1.12e-01
# Alpha[1] (ARCH Term): 0.9919
#
# Model Evaluation:
# Log-Likelihood: -156057.70
# AIC (Akaike Information Criterion): 312121.39
# BIC (Bayesian Information Criterion): 312148.53
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: NC0.5
# ARCH Model Results:
#
# Omega (Intercept): 1.82e-01
# Alpha[1] (ARCH Term): 1.0000
#
# Model Evaluation:
# Log-Likelihood: -157449.70
# AIC (Akaike Information Criterion): 314905.40
# BIC (Bayesian Information Criterion): 314932.53
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: NC1.0
# ARCH Model Results:
#
# Omega (Intercept): 4.90e-02
# Alpha[1] (ARCH Term): 0.9864
#
# Model Evaluation:
# Log-Likelihood: -51065.10
# AIC (Akaike Information Criterion): 102136.20
# BIC (Bayesian Information Criterion): 102163.34
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: NC2.5
# ARCH Model Results:
#
# Omega (Intercept): 1.05e+03
# Alpha[1] (ARCH Term): 0.2991
#
# Model Evaluation:
# Log-Likelihood: -1445792.45
# AIC (Akaike Information Criterion): 2891590.89
# BIC (Bayesian Information Criterion): 2891618.03
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is low, suggesting that past variances have a weaker effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: PM1.0
# ARCH Model Results:
#
# Omega (Intercept): 8.51e-03
# Alpha[1] (ARCH Term): 1.0000
#
# Model Evaluation:
# Log-Likelihood: -40921.71
# AIC (Akaike Information Criterion): 81849.43
# BIC (Bayesian Information Criterion): 81876.56
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: PM2.5
# c:\Users\MACH-DE-28\anaconda3\envs\test\lib\site-packages\arch\univariate\base.py:765: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# ARCH Model Results:
#
# Omega (Intercept): 4.58e-02
# Alpha[1] (ARCH Term): 0.8999
#
# Model Evaluation:
# Log-Likelihood: -49136.87
# AIC (Akaike Information Criterion): 98279.74
# BIC (Bayesian Information Criterion): 98306.87
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: Pressure[hPa]
# ARCH Model Results:
#
# Omega (Intercept): 4.22e-05
# Alpha[1] (ARCH Term): 1.0000
#
# Model Evaluation:
# Log-Likelihood: -5692.35
# AIC (Akaike Information Criterion): 11390.69
# BIC (Bayesian Information Criterion): 11417.83
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: Raw Ethanol
# ARCH Model Results:
#
# Omega (Intercept): 8.24e+01
# Alpha[1] (ARCH Term): 0.9835
#
# Model Evaluation:
# Log-Likelihood: -394321.92
# AIC (Akaike Information Criterion): 788649.84
# BIC (Bayesian Information Criterion): 788676.98
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: Raw H2
# ARCH Model Results:
#
# Omega (Intercept): 7.39e+01
# Alpha[1] (ARCH Term): 1.0000
#
# Model Evaluation:
# Log-Likelihood: -376560.51
# AIC (Akaike Information Criterion): 753127.02
# BIC (Bayesian Information Criterion): 753154.15
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: TVOC[ppb]
# ARCH Model Results:
#
# Omega (Intercept): 6.10e+06
# Alpha[1] (ARCH Term): 0.5555
#
# Model Evaluation:
# Log-Likelihood: -555591.88
# AIC (Akaike Information Criterion): 1111189.77
# BIC (Bayesian Information Criterion): 1111216.90
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is low, suggesting that past variances have a weaker effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: Temperature[C]
# ARCH Model Results:
#
# Omega (Intercept): 7.08e-03
# Alpha[1] (ARCH Term): 1.0000
#
# Model Evaluation:
# Log-Likelihood: -194777.40
# AIC (Akaike Information Criterion): 389560.81
# BIC (Bayesian Information Criterion): 389587.94
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------
#
# arch_test for column: eCO2[ppm]
# ARCH Model Results:
#
# Omega (Intercept): 1.98e+01
# Alpha[1] (ARCH Term): 1.0000
#
# Model Evaluation:
# Log-Likelihood: -260330.64
# AIC (Akaike Information Criterion): 520667.27
# BIC (Bayesian Information Criterion): 520694.41
#
# Interpretation:
# Omega value is low, indicating a low level of volatility in the model.
# Alpha[1] is high, suggesting that past variances have a strong effect on current volatility.
# ------------------------------------------------------------------------------------------------------------------

# %%
# Check VIF Test
vif_test(df)
# Out:
# Variable: const, VIF: 1500293.82, Interpretation: High multicollinearity
# Variable: CNT, VIF: 3.19, Interpretation: Low multicollinearity
# Variable: Fire Alarm, VIF: 2.51, Interpretation: Low multicollinearity
# Variable: Humidity[%], VIF: 3.47, Interpretation: Low multicollinearity
# Variable: NC0.5, VIF: 73837370004.52, Interpretation: High multicollinearity
# Variable: NC1.0, VIF: 1684848345443.51, Interpretation: High multicollinearity
# Variable: NC2.5, VIF: 667694533338.84, Interpretation: High multicollinearity
# Variable: PM1.0, VIF: 97294136283.75, Interpretation: High multicollinearity
# Variable: PM2.5, VIF: 459926432533.75, Interpretation: High multicollinearity
# Variable: Pressure[hPa], VIF: 3.05, Interpretation: Low multicollinearity
# Variable: Raw Ethanol, VIF: 7.96, Interpretation: Moderate multicollinearity
# Variable: Raw H2, VIF: 3.42, Interpretation: Low multicollinearity
# Variable: TVOC[ppb], VIF: 5.18, Interpretation: Moderate multicollinearity
# Variable: Temperature[C], VIF: 1.14, Interpretation: Low multicollinearity
# Variable: eCO2[ppm], VIF: 2.87, Interpretation: Low multicollinearity
