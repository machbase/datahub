# %% [markdown]
# # Oil Temperature Forecasting

# %% [markdown]
# ## Import Necessary Libraries

# %%
## Import necessary libraries
import pandas as pd
import numpy as np
import random 
from urllib.parse import quote, unquote
from datetime import timedelta
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

## Import libraries for the model
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm.notebook import trange
from sklearn.metrics import mean_squared_error, r2_score

## Set path for saving model training results
import os
os.makedirs('./result', exist_ok=True)

## Set Cuda for computation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

## Set random seed
def set_seed(seed_val):
    random.seed(seed_val)
    np.random.seed(seed_val)
    torch.manual_seed(seed_val)
    torch.cuda.manual_seed_all(seed_val)

# Set seed
seed_val = 77
set_seed(seed_val)
# Out:
# cuda

# %% [markdown]
# ## Selecting Data Columns
# * Tag names are loaded in sequential order.
# * The process of selecting the required tag names from the tag name list.

# %%
# Function to display tag names
def show_column(URL):
    
    # Load tag name data
    df = pd.read_csv(URL)
    
    # Convert to list format
    df = df.values.reshape(-1)
    
    return df.tolist()

# %%
## Set parameters for displaying tag names
table = 'elec_trans'

NAME_URL = f'http://127.0.0.1:5654/db/tql/datahub/api/v1/get-tag-names.tql?table={table}'

## Generate tag name list
tag_name = show_column(NAME_URL)

# %%
tag_name
# Out:
# ['HUFL_h1',
#  'HUFL_h2',
#  'HUFL_m1',
#  'HUFL_m2',
#  'HULL_h1',
#  'HULL_h2',
#  'HULL_m1',
#  'HULL_m2',
#  'LUFL_h1',
#  'LUFL_h2',
#  'LUFL_m1',
#  'LUFL_m2',
#  'LULL_h1',
#  'LULL_h2',
#  'LULL_m1',
#  'LULL_m2',
#  'MUFL_h1',
#  'MUFL_h2',
#  'MUFL_m1',
#  'MUFL_m2',
#  'MULL_h1',
#  'MULL_h2',
#  'MULL_m1',
#  'MULL_m2',
#  'OT_h1',
#  'OT_h2',
#  'OT_m1',
#  'OT_m2']

# %% [markdown]
# ## Converting TAG Name Format
# * After checking all the Tag Names from the Elec_Trans dataset in the previous step, extract only the columns to be used and convert them into parameter format.
# * Use tag names related to the 1-hour interval data from Region 1 in China.

# %%
# Set the desired tag names
tags = ['HUFL_h1', 'HULL_h1', 'LUFL_h1', 'LULL_h1', 'MUFL_h1', 'MULL_h1', 'OT_h1']

# Wrap each item in the list with single quotes and separate with commas
tags_ = ",".join(f"'{tag}'" for tag in tags)

# Check the selected tag names
print(tags_)
# Out:
# 'HUFL_h1','HULL_h1','LUFL_h1','LULL_h1','MUFL_h1','MULL_h1','OT_h1'

# %% [markdown]
# ## Load Elec_Trans Dataset
# * Load the data using the Tag Names.

# %%
# Data loading function
def data_load(table, name, start_time, end_time, timeformat):
    
    # Load the data
    df = pd.read_csv(f'http://127.0.0.1:5654/db/tql/datahub/api/v1/select-rawdata.tql?table={table}&name={name}&start={start_time}&end={end_time}&timeformat={timeformat}')
    
    # Transform to data by the same time zone
    df = df.pivot_table(index='TIME', columns='NAME', values='VALUE', aggfunc='first').reset_index()
    
    # Convert 'TIME' column to datetime format
    df['TIME'] = pd.to_datetime(df['TIME'])
    df = df.set_index(pd.to_datetime(df['TIME']))
    df = df.drop(['TIME'], axis=1)
    
    # Time series decomposition
    decomposition = seasonal_decompose(df['OT_h1'], model='additive', period=24)

    # Use only the trend
    trend = decomposition.trend 
    
    # Create a new DataFrame
    df = pd.DataFrame(trend.dropna().values, columns=['value'])
    df.index = trend.dropna().index
    
    # Create new columns with window applied
    df['lag1'] = df['value'].shift(1)  # Previous 1-hour data
    df['lag2'] = df['value'].shift(2)  # Previous 2-hour data
    df['lag3'] = df['value'].shift(3)  # Previous 3-hour data 
    
    # Remove missing values
    df = df.dropna()
    
    # Move 'value' column to the end
    df['value'] = df.pop('value')

    return df

# %%
# Data time loading function
def time_data_load(table, name, start_time, end_time, timeformat):
    
    target = 'time'
    
    # Load the data
    df = pd.read_csv(f"http://127.0.0.1:5654/db/tql/datahub/api/v1/select-rawdata.tql?target={target}&table={table}&name={name}&start={start_time}&end={end_time}&timeformat={timeformat}")
    
    # Create a dummy value column for resampling
    df['value'] = 0
    
    # Perform resampling
    df['time'] = pd.to_datetime(df['time'])
    df.set_index('time', inplace=True)
    # Determine resampling units based on the data and perform resampling
    df = df.resample('1h').mean()
    
    # Remove missing values
    df = df.dropna()
    
    # Remove the dummy value column
    df = df.drop(['value'], axis=1)
    
    return df

# %%
# Time update function
# Update start and end times based on batch size
def update_time(time_df, start_time, batch_size):
    
    # Calculate how many data points need to be loaded
    time = batch_size 
    
    # Check the index number of the current time
    # If not found, set to the first index as there is no data for the current time
    try:
        index_now = time_df.index.get_loc(start_time)
    except KeyError:
        index_now = 0
    
    # Set the end time for the batch data based on the current time
    end_time_ = str(time_df.index[index_now + time] + timedelta(seconds=1))
    
    # Set the index number for the next start time
    index_next = index_now + time - 26
    
    # Set the next start time
    next_start_time_ = str(time_df.index[index_next])
    
    # URL encoding
    start_time_ = quote(start_time)
    end_time_ = quote(end_time_)
    next_start_time_ = quote(next_start_time_)
    
    return start_time_, end_time_, next_start_time_, index_next

# %% [markdown]
# ## Model Configuration
# * Using BILSTM model.

# %%
# BILSTM Model Configuration
class BILSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers,dropout=0.2, bidirectional=False):
        super(BILSTM, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size, hidden_size, num_layers, 
                            batch_first=True, dropout=dropout, bidirectional=bidirectional)
        
        self.lstm2 = nn.LSTM(2*hidden_size, 2*hidden_size, num_layers, 
                    batch_first=True,dropout=dropout, bidirectional=bidirectional)
        
        self.fc = nn.Linear(2* hidden_size * (2 if bidirectional else 1), 1)
        
        self.layer_norm = nn.LayerNorm(3)

    def forward(self, x):
        out, (h_n, c_n) = self.lstm1(x)
        out, (h_n, c_n) = self.lstm2(out)
        out = self.fc(out[:, -1, :])
        return out

# %%
# Model configuration parameters

# Number of input data columns
input_dim = 3

# Size of the hidden state
hidden_dim = 64

# Number of layers
num_layers = 2

# Learning rate
learning_rate = 0.01

# Model configuration
model = BILSTM(input_dim, hidden_dim, num_layers, bidirectional=True).to(device)

# Configure loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Check the model architecture
print(model)
# Out:
# BILSTM(
#   (lstm1): LSTM(3, 64, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (lstm2): LSTM(128, 128, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (layer_norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
# )

# %% [markdown]
# ## Model Training
# * Proceed by loading only the necessary batch size of data for training.
# * Save the model with the best loss based on the validation data during training.

# %%
# Model training function
def train(table, name, timeformat, model, batch_size_train, epochs, scaler_data, scaler_target, time_df_train):
    
    # Initialize training loss
    train_loss = []

    # Initialize best loss value
    best_Loss = np.inf

    for epoch in epochs:
        
        # Set the model to training mode
        model.train()
        
        # Initialize loss and total step
        running_loss = 0.0
        total_step = 0
        
        # Set initial start time
        start_time_ = str(time_df_train.index[0])
        
        # Set end time
        end_time_train = str(time_df_train.index[-1])
        
        # Use a while loop to call data 
        while start_time_ < end_time_train:
            
            # Set the time for loading data based on the batch size
            start_time_, end_time_, next_start_time_, index_next = update_time(time_df_train, start_time_, batch_size_train)
        
            # Load batch data
            data = data_load(table, name, start_time_, end_time_, timeformat)
            
            # Apply MinMax scaler
            data_scaled = scaler_data.fit_transform(data.iloc[:, :-1])
            target_scaled = scaler_target.fit_transform(data.iloc[:, -1:])
            
            # Set up the DataFrame
            data = pd.DataFrame(data_scaled)
            data['target'] = target_scaled
            
            # Print if the loaded data is empty
            if len(data) == 0:
                print("No data available.")
            
            # Input the data into the model when it accumulates to the batch size
            if len(data) == batch_size_train - 26:
                
                # Check total batch count
                total_step += 1
                
                # Convert data to numpy arrays
                input_data = np.array(data.iloc[:, :-1])
                input_target = np.array(data.iloc[:, -1:])
                
                # Convert data to Tensor
                input_data = torch.tensor(input_data, dtype=torch.float32).to(device).float()
                input_target = torch.tensor(input_target, dtype=torch.float32).to(device).float()
                
                # Optimize the optimizer
                optimizer.zero_grad()
                
                # Input to the model
                outputs = model(input_data.unsqueeze(1))
        
                # Calculate loss
                loss = criterion(outputs, input_target)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                
                # Reset batch data
                data = []

            # Set the next start time
            start_time_ = unquote(next_start_time_)
            
            # Prevent fetching beyond the last time
            if index_next + batch_size_train + 26 >= len(time_df_train):
                break

        # Print training loss
        train_loss.append(running_loss / total_step)
        print(f'\ntrain loss: {np.mean(train_loss)}')
        
        # Save the model if it has the best loss
        if best_Loss > np.mean(train_loss):
            best_Loss = np.mean(train_loss)
            torch.save(model, f'./result/Elec_trans_BILSTM_New_Batch.pt')
            print('Model saved')
        epochs.set_postfix_str(f"epoch = {epoch}, best_Loss = {best_Loss}")
        
    return model

# %%
########################################### Training Parameter Settings ################################################
# Set tag table name
table = 'elec_trans'
# Set tag name
name = quote(tags_, safe=":/")
# Set time format
timeformat = 'default'
# Set the start time for the train data
start_time_train = '2016-07-01 00:00:00'
# Set the end time for the train data
end_time_train = '2018-05-31 23:00:00'
# Set batch size considering train data dropped during preprocessing
batch_size_train = 64 + 26
# Set number of epochs
epochs = trange(100, desc='training')
# Set scalers
scaler_data = MinMaxScaler()
scaler_target = MinMaxScaler()
# Load training time list
time_df_train = time_data_load(table, name, quote(start_time_train), quote(end_time_train), timeformat)

# Train the model
train(table, name, timeformat, model, batch_size_train, epochs, scaler_data, scaler_target, time_df_train)
# Out:
# training:   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 0.02054569041989815
# Model saved
#
# train loss: 0.011291355565252759
# Model saved
#
# train loss: 0.008155031081285782
# Model saved
#
# train loss: 0.0064876972297859955
# Model saved
#
# train loss: 0.005542463526007954
# Model saved
#
# train loss: 0.004841030362185707
# Model saved
#
# train loss: 0.004325415648659665
# Model saved
#
# train loss: 0.0039157028826579945
# Model saved
#
# train loss: 0.0036178509770596096
# Model saved
#
# train loss: 0.0033618715668279563
# Model saved
#
# train loss: 0.0031661649578050553
# Model saved
#
# train loss: 0.0029968760586290555
# Model saved
#
# train loss: 0.002855398978206761
# Model saved
#
# train loss: 0.0027248024773729117
# Model saved
#
# train loss: 0.00260953539427867
# Model saved
#
# train loss: 0.002506526253378714
# Model saved
#
# train loss: 0.0024174849368977487
# Model saved
#
# train loss: 0.0023343131527765156
# Model saved
#
# train loss: 0.0022588965586736592
# Model saved
#
# train loss: 0.0021859584296570677
# Model saved
#
# train loss: 0.0021183897909708574
# Model saved
#
# train loss: 0.002056781907476137
# Model saved
#
# train loss: 0.0019980450693741366
# Model saved
#
# train loss: 0.001944239824685214
# Model saved
#
# train loss: 0.0018945010648875307
# Model saved
#
# train loss: 0.001846925826416601
# Model saved
#
# train loss: 0.001803304769205072
# Model saved
#
# train loss: 0.0017629373764579993
# Model saved
#
# train loss: 0.0017252698443417165
# Model saved
#
# train loss: 0.0016897358190605628
# Model saved
#
# train loss: 0.001656512750352023
# Model saved
#
# train loss: 0.0016239611454301635
# Model saved
#
# train loss: 0.0015929881214005463
# Model saved
#
# train loss: 0.0015636080531513817
# Model saved
#
# train loss: 0.0015359845790559577
# Model saved
#
# train loss: 0.001509576950749053
# Model saved
#
# train loss: 0.001484036186162015
# Model saved
#
# train loss: 0.0014597706635161216
# Model saved
#
# train loss: 0.001437079392122541
# Model saved
#
# train loss: 0.001415077686516998
# Model saved
#
# train loss: 0.0013933894176747232
# Model saved
#
# train loss: 0.001374097578565737
# Model saved
#
# train loss: 0.0013547626251152823
# Model saved
#
# train loss: 0.0013357157127188142
# Model saved
#
# train loss: 0.001317613974133983
# Model saved
#
# train loss: 0.0013004448847635046
# Model saved
#
# train loss: 0.0012837971268265193
# Model saved
#
# train loss: 0.0012679173819268427
# Model saved
#
# train loss: 0.001252747028092681
# Model saved
#
# train loss: 0.0012380911261511772
# Model saved
#
# train loss: 0.001223351901884733
# Model saved
#
# train loss: 0.0012093193885906101
# Model saved
#
# train loss: 0.0011955710653583345
# Model saved
#
# train loss: 0.0011824965519014673
# Model saved
#
# train loss: 0.001170455247288774
# Model saved
#
# train loss: 0.0011585604021646936
# Model saved
#
# train loss: 0.0011473660753026495
# Model saved
#
# train loss: 0.0011365737336094682
# Model saved
#
# train loss: 0.001125923674066972
# Model saved
#
# train loss: 0.001115774385740261
# Model saved
#
# train loss: 0.001106435527728401
# Model saved
#
# train loss: 0.0010970186971290248
# Model saved
#
# train loss: 0.0010885703231687483
# Model saved
#
# train loss: 0.0010796714841004354
# Model saved
#
# train loss: 0.0010710681152218287
# Model saved
#
# train loss: 0.0010627809499101557
# Model saved
#
# train loss: 0.0010544578979324588
# Model saved
#
# train loss: 0.0010461252878266826
# Model saved
#
# train loss: 0.0010382344028566533
# Model saved
#
# train loss: 0.0010305241790768771
# Model saved
#
# train loss: 0.001022621136121478
# Model saved
#
# train loss: 0.0010152443819341338
# Model saved
#
# train loss: 0.0010077568050321482
# Model saved
#
# train loss: 0.0010006196181137246
# Model saved
#
# train loss: 0.0009938552377792044
# Model saved
#
# train loss: 0.0009870161649767372
# Model saved
#
# train loss: 0.000980201498400569
# Model saved
#
# train loss: 0.0009736878246287616
# Model saved
#
# train loss: 0.0009672381439117633
# Model saved
#
# train loss: 0.0009608725962565607
# Model saved
#
# train loss: 0.0009546050700468226
# Model saved
#
# train loss: 0.0009482850639740424
# Model saved
#
# train loss: 0.000942379654312959
# Model saved
#
# train loss: 0.0009364790880911362
# Model saved
#
# train loss: 0.0009308747523037709
# Model saved
#
# train loss: 0.0009250689712113126
# Model saved
#
# train loss: 0.0009195309555351179
# Model saved
#
# train loss: 0.0009141596668274541
# Model saved
#
# train loss: 0.0009088327788097906
# Model saved
#
# train loss: 0.0009036097463200894
# Model saved
#
# train loss: 0.0008985226631503091
# Model saved
#
# train loss: 0.000893424187810963
# Model saved
#
# train loss: 0.0008884149243324764
# Model saved
#
# train loss: 0.0008836614673580346
# Model saved
#
# train loss: 0.0008786923268008023
# Model saved
#
# train loss: 0.0008739336186990411
# Model saved
#
# train loss: 0.000869272881856028
# Model saved
#
# train loss: 0.000864545459382004
# Model saved
#
# train loss: 0.0008600402244821343
# Model saved
#
# train loss: 0.0008556504068500655
# Model saved
# BILSTM(
#   (lstm1): LSTM(3, 64, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (lstm2): LSTM(128, 128, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (layer_norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
# )

# %% [markdown]
# ## Model Testing

# %%
# Model testing function  
def test(table, name, timeformat, model, batch_size_test, scaler_data, scaler_target, time_df_test):
    with torch.no_grad():
                
        model.eval()
        
        # Initial settings 
        output_test = []
        output_target = []
            
        # Set the initial start time
        start_time_t = str(time_df_test.index[0])
        
        # Set the end time
        end_time_test = str(time_df_test.index[-1])
        
        # Use a while loop to call data 
        while start_time_t < end_time_test:
            
            # Set the time for loading data based on the batch size
            start_time_t, end_time_t, next_start_time_t, index_next_t = update_time(time_df_test, start_time_t, batch_size_test)
        
            # Load batch data
            data_t = data_load(table, name, start_time_t, end_time_t, timeformat)
            
            # Apply MinMax scaler
            data_scaled = scaler_data.fit_transform(data_t.iloc[:,:-1])
            target_scaled = scaler_target.fit_transform(data_t.iloc[:,-1:])
            
            # Set the DataFrame
            data_t = pd.DataFrame(data_scaled)
            data_t['target'] = target_scaled
            
            # Print if the loaded data is empty 
            if len(data_t) == 0:
                print("No data available.")
            
            # Move to the next batch if the data size matches the batch size
            if len(data_t) == batch_size_test - 26:
                
                # Convert data to numpy arrays
                input_data_t = np.array(data_t.iloc[:, :-1])
                input_target_t = np.array(data_t.iloc[:, -1:])

                # Convert data to Tensor
                input_data_t = torch.tensor(input_data_t, dtype=torch.float32).to(device).float()
                input_target_t = torch.tensor(input_target_t, dtype=torch.float32).to(device).float()
                
                # Model input
                outputs_t = model(input_data_t.unsqueeze(1))
                
                output_test.append(outputs_t)
                output_target.append(input_target_t)
                
                # Reset the batch
                data_t = []

            # Set the next start time    
            start_time_t = unquote(next_start_time_t)
            
            # Prevent loading beyond the last time
            if index_next_t + batch_size_test + 26 >= len(time_df_test):
                break
        
        # Combine the tensors into one
        combined_tensor_target = torch.cat(output_target, dim=0)
        combined_tensor_pred = torch.cat(output_test, dim=0)

        # Use only the last values of the window
        last_values_target = combined_tensor_target[:, -1].cpu()
        last_values_pred = combined_tensor_pred.cpu()

        # Inverse transform using MinMaxScaler 
        real_values = scaler_target.inverse_transform(last_values_target.numpy().reshape(-1, 1))
        real_pred_values = scaler_target.inverse_transform(last_values_pred.numpy().reshape(-1, 1)) 
        
        return real_values, real_pred_values

# %%
########################################### Test Parameter Settings ################################################
# Load the best model
model_ = torch.load(f'./result/Elec_trans_BILSTM_New_Batch.pt')
# Set the start time for the test data
start_time_test = '2018-05-31 00:00:00'
# Set the end time for the test data
end_time_test = '2018-07-01 00:00:00'
# Set the batch size considering the test data dropped during preprocessing
batch_size_test = 64 + 26
# Load the test time list
time_df_test = time_data_load(table, name, quote(start_time_test), quote(end_time_test), timeformat)

# Perform the test
real_values, real_pred_values = test(table, name, timeformat, model_, batch_size_test, scaler_data, scaler_target, time_df_test)

# %% [markdown]
# ## Model Performance Evaluation

# %%
# Calculate MSE
mse = mean_squared_error(real_values, real_pred_values)
print("Mean Squared Error:", mse)

# Calculate R² Score
r2 = r2_score(real_values, real_pred_values)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 0.012785136
# R² Score: 0.9857372672326377

# %%
# Compare the test results: Actual values vs Predicted values
plt.figure(figsize=(12, 6))
plt.plot(real_values, label='Actual', color='blue')
plt.plot(real_pred_values, label='Predicted', color='red', alpha=0.7)
plt.title('Actual vs Predicted')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.show()
