# %% [markdown]
# # Oil Temperature Prediction

# %% [markdown]
# ## Import Necessary Libraries

# %%
## Import necessary libraries
import pandas as pd
import numpy as np
import random 
from urllib.parse import quote
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler

## Import libraries for the model
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from tqdm.notebook import trange
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

## Set path for saving model training results 
import os
os.makedirs('./result', exist_ok=True)

## Set Cuda for computation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

## Set random seed
def set_seed(seed_val):
    random.seed(seed_val)
    np.random.seed(seed_val)
    torch.manual_seed(seed_val)
    torch.cuda.manual_seed_all(seed_val)

# Set seed
seed_val = 77
set_seed(seed_val)
# Out:
# cuda

# %% [markdown]
# ## Selecting Data Columns
# * Tag names are loaded in sequential order.
# * The process of selecting the required tag names from the tag name list.

# %%
# Function to display tag names
def show_column(URL):
    
    # Load tag name data
    df = pd.read_csv(URL)
    
    # Convert to list format
    df = df.values.reshape(-1)
    
    return df.tolist()

# %%
## Set parameters for displaying tag names
table = 'elec_trans'

NAME_URL = f'http://127.0.0.1:5654/db/tql/datahub/api/v1/get-tag-names.tql?table={table}'

## Generate tag name list
tag_name = show_column(NAME_URL)

# %%
tag_name
# Out:
# ['HUFL_h1',
#  'HUFL_h2',
#  'HUFL_m1',
#  'HUFL_m2',
#  'HULL_h1',
#  'HULL_h2',
#  'HULL_m1',
#  'HULL_m2',
#  'LUFL_h1',
#  'LUFL_h2',
#  'LUFL_m1',
#  'LUFL_m2',
#  'LULL_h1',
#  'LULL_h2',
#  'LULL_m1',
#  'LULL_m2',
#  'MUFL_h1',
#  'MUFL_h2',
#  'MUFL_m1',
#  'MUFL_m2',
#  'MULL_h1',
#  'MULL_h2',
#  'MULL_m1',
#  'MULL_m2',
#  'OT_h1',
#  'OT_h2',
#  'OT_m1',
#  'OT_m2']

# %% [markdown]
# ## Converting TAG Name Format
# * After checking all the Tag Names from the Elec_Trans dataset in the previous step, extract only the columns to be used and convert them into parameter format.
# * Use tag names related to the 1-hour interval data from Region 1 in China.

# %%
# Set the desired tag names
tags = ['HUFL_h1', 'HULL_h1', 'LUFL_h1', 'LULL_h1', 'MUFL_h1', 'MULL_h1', 'OT_h1']

# Wrap each item in the list with single quotes and separate with commas
tags_ = ",".join(f"'{tag}'" for tag in tags)

# Check the selected tag names
print(tags_)
# Out:
# 'HUFL_h1','HULL_h1','LUFL_h1','LULL_h1','MUFL_h1','MULL_h1','OT_h1'

# %% [markdown]
# ## Load Elec_Trans Dataset
# * Load the data using the Tag Names.

# %%
# Data loading parameter settings

# Set the tag table name
table = 'elec_trans'
# Set the tag names
name = quote(tags_, safe=":/")
# Set the time format
timeformat = 'default'
# Set the data start time
start_time = quote('2016-07-01 00:00:00')
# Set the data end time
end_time = quote('2018-06-26 19:00:00')

# %%
# Data loading function
def data_load(table, name, start_time, end_time, timeformat):
    
    # Load the data
    df = pd.read_csv(f'http://127.0.0.1:5654/db/tql/datahub/api/v1/select-rawdata.tql?table={table}&name={name}&start={start_time}&end={end_time}&timeformat={timeformat}')
    
    # Transform to data by the same time zone
    df = df.pivot_table(index='TIME', columns='NAME', values='VALUE', aggfunc='first').reset_index()
    
    # Convert 'TIME' column to datetime format
    df['TIME'] = pd.to_datetime(df['TIME'])
    df = df.set_index(pd.to_datetime(df['TIME']))
    df = df.drop(['TIME'], axis=1)
    
    # Time series decomposition
    decomposition = seasonal_decompose(df['OT_h1'], model='additive', period=24)

    # Use only the trend
    trend = decomposition.trend 
    
    # Create a new DataFrame
    df = pd.DataFrame(trend.dropna().values, columns=['value'])
    df.index = trend.dropna().index
    
    # Create new columns with window applied
    df['lag1'] = df['value'].shift(1)  # Previous 1-hour data
    df['lag2'] = df['value'].shift(2)  # Previous 2-hour data
    df['lag3'] = df['value'].shift(3)  # Previous 3-hour data 
    
    # Remove missing values
    df = df.dropna()
    
    # Move 'value' column to the end
    df['value'] = df.pop('value')

    return df

# %%
# Load the data
df = data_load(table, name, start_time, end_time, timeformat)

# Split the data into training and testing sets

# Set training data to include data before June 2018
train = df[df.index < '2018-06-01']

# Set testing data to include data after June 2018
test = df[df.index > '2018-06-01']

train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

df
# Out:
#                           lag1       lag2       lag3      value
# TIME
# 2016-07-01 15:00:00  20.180750  20.510500  20.875438  19.930125
# 2016-07-01 16:00:00  19.930125  20.180750  20.510500  19.828979
# 2016-07-01 17:00:00  19.828979  19.930125  20.180750  19.839250
# 2016-07-01 18:00:00  19.839250  19.828979  19.930125  19.808500
# 2016-07-01 19:00:00  19.808500  19.839250  19.828979  19.713250
# ...                        ...        ...        ...        ...
# 2018-06-26 03:00:00   9.937875   9.984792  10.031708   9.901229
# 2018-06-26 04:00:00   9.901229   9.937875   9.984792   9.858729
# 2018-06-26 05:00:00   9.858729   9.901229   9.937875   9.805958
# 2018-06-26 06:00:00   9.805958   9.858729   9.901229   9.751729
# 2018-06-26 07:00:00   9.751729   9.805958   9.858729   9.701896
#
# [17393 rows x 4 columns]

# %% [markdown]
# ## Data Preprocessing
# * 1 Decomposition -> Applied in advance
# * 2 Min-Max Scaling

# %% [markdown]
# ### 2. Min-Max Scaling

# %%
# Set a separate scaler for oil temperature for the subsequent reconstruction process

# Data scaler setup
scaler_data = MinMaxScaler()

# Apply data scaler
train_data = scaler_data.fit_transform(train.iloc[:, :-1].values)
test_data = scaler_data.transform(test.iloc[:, :-1].values)

# Target scaler setup
scaler_target = MinMaxScaler()

# Apply target scaler
train_target = scaler_target.fit_transform(train.iloc[:, -1:].values)
test_target = scaler_target.transform(test.iloc[:, -1:].values)

# DataFrame setup
train_scaled = pd.DataFrame(train_data)
train_scaled['value'] = train_target

test_scaled = pd.DataFrame(test_data)
test_scaled['value'] = test_target

# %% [markdown]
# ## Dataset & Loader Setup

# %%
# Dataset class setup
class Dataset():

    def __init__(self, df):
        self.data = df.iloc[:, :-1]
        self.target = df.iloc[:, -1]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        # Process feature data
        input_time_data = self.data.iloc[index, :]
        input_time_data = torch.Tensor(input_time_data).expand(1, input_time_data.shape[0])

        # Process target value
        target = torch.Tensor([self.target.iloc[index]])

        return input_time_data, target

# %%
# Dataset setup
train_ = Dataset(train_scaled)
test_ = Dataset(test_scaled)

# DataLoader setup
train_dataloader = DataLoader(train_, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_, batch_size=1, shuffle=False)

# %%
# Verify DataLoader application and check the shape of the input data
print(list(train_dataloader)[0][0].shape)
# Out:
# torch.Size([64, 1, 3])

# %% [markdown]
# ## Model Configuration
# * Using BILSTM model.

# %%
# BILSTM Model Configuration
class BILSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers,dropout=0.2, bidirectional=False):
        super(BILSTM, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size, hidden_size, num_layers, 
                            batch_first=True, dropout=dropout, bidirectional=bidirectional)
        
        self.lstm2 = nn.LSTM(2*hidden_size, 2*hidden_size, num_layers, 
                    batch_first=True,dropout=dropout, bidirectional=bidirectional)
        
        self.fc = nn.Linear(2* hidden_size * (2 if bidirectional else 1), 1)
        
        self.layer_norm = nn.LayerNorm(3)

    def forward(self, x):
        out, (h_n, c_n) = self.lstm1(x)
        out, (h_n, c_n) = self.lstm2(out)
        out = self.fc(out[:, -1, :])
        return out

# %%
# Model configuration parameters

# Number of input data columns
# Last number in print(list(train_dataloader)[0][0].shape)
input_dim = 3

# Size of the hidden state
hidden_dim = 64

# Number of layers
num_layers = 2

# Learning rate
learning_rate = 0.01

# Model configuration
model = BILSTM(input_dim, hidden_dim, num_layers, bidirectional=True).to(device)

# Configure loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Check the model architecture
print(model)
# Out:
# BILSTM(
#   (lstm1): LSTM(3, 64, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (lstm2): LSTM(128, 128, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (layer_norm): LayerNorm((3,), eps=1e-05, elementwise_affine=True)
# )

# %% [markdown]
# ## Model Training
# * Save the model with the best loss based on the validation data during training.

# %%
# Initialize training loss
train_loss = []
# Initialize total step
total_step = len(train_dataloader)
# Set number of epochs
epoch_in = trange(100, desc='training')
# Initialize best loss value
best_Loss= np.inf

# Start model training
for epoch in epoch_in:

    model.train()
    
    # Initialize loss
    running_loss = 0.0

    for batch_idx, train_data in enumerate(train_dataloader):

        inputs = train_data[0].to(device).float()
        target = train_data[1].to(device).float()

        optimizer.zero_grad()
        
        # Input to the model
        outputs = model(inputs)
        
        # Calculate loss
        loss = criterion(outputs.squeeze(), target[:, -1])
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

    # Print training loss
    train_loss.append(running_loss/total_step)
    print(f'\ntrain loss: {np.mean(train_loss)}')

    # Save the model if it has the best loss
    if best_Loss > np.mean(train_loss):
        best_Loss = np.mean(train_loss)
        torch.save(model, f'./result/Elec_trans_BILSTM_General.pt')
        print('Model saved')
    epoch_in.set_postfix_str(f"epoch = {epoch}, best_Loss = {best_Loss}")
# Out:
# training:   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 0.003532809985872622
# Model saved
#
# train loss: 0.0018911527373977163
# Model saved
#
# train loss: 0.001331287449807786
# Model saved
#
# train loss: 0.0010913439790552044
# Model saved
#
# train loss: 0.0009106893305775856
# Model saved
#
# train loss: 0.0007881031878632399
# Model saved
#
# train loss: 0.0007061836602559646
# Model saved
#
# train loss: 0.0006367872802953231
# Model saved
#
# train loss: 0.0005893040956225718
# Model saved
#
# train loss: 0.0005461556925864942
# Model saved
#
# train loss: 0.0005082131767381562
# Model saved
#
# train loss: 0.0004783651161400282
# Model saved
#
# train loss: 0.00045237691124040095
# Model saved
#
# train loss: 0.00042711650736500874
# Model saved
#
# train loss: 0.00040533924607090985
# Model saved
#
# train loss: 0.0003854613844906304
# Model saved
#
# train loss: 0.0003695699499049148
# Model saved
#
# train loss: 0.00035560752514704984
# Model saved
#
# train loss: 0.00034138981135102846
# Model saved
#
# train loss: 0.00032883887457715665
# Model saved
#
# train loss: 0.0003172394131560083
# Model saved
#
# train loss: 0.00030629666232280224
# Model saved
#
# train loss: 0.0002973552875849936
# Model saved
#
# train loss: 0.0002884623018146875
# Model saved
#
# train loss: 0.00027969680726085524
# Model saved
#
# train loss: 0.00027154617033443065
# Model saved
#
# train loss: 0.0002645839277966401
# Model saved
#
# train loss: 0.00025770311578742546
# Model saved
#
# train loss: 0.00025162676037158283
# Model saved
#
# train loss: 0.0002461599386502074
# Model saved
#
# train loss: 0.00024092652490340286
# Model saved
#
# train loss: 0.0002356847666515057
# Model saved
#
# train loss: 0.00023007218763091824
# Model saved
#
# train loss: 0.00022513890296259808
# Model saved
#
# train loss: 0.00022031705113481024
# Model saved
#
# train loss: 0.00021575521339325127
# Model saved
#
# train loss: 0.00021168000150660154
# Model saved
#
# train loss: 0.00020765431525097099
# Model saved
#
# train loss: 0.00020376010337344827
# Model saved
#
# train loss: 0.00019987521313263287
# Model saved
#
# train loss: 0.00019653240057072808
# Model saved
#
# train loss: 0.0001931020203226891
# Model saved
#
# train loss: 0.00018970846881745656
# Model saved
#
# train loss: 0.0001866292708978417
# Model saved
#
# train loss: 0.00018361029531770306
# Model saved
#
# train loss: 0.00018070825722127262
# Model saved
#
# train loss: 0.00017797983860154938
# Model saved
#
# train loss: 0.00017543576734999002
# Model saved
#
# train loss: 0.00017293316121567637
# Model saved
#
# train loss: 0.0001704489235087493
# Model saved
#
# train loss: 0.0001682309620253632
# Model saved
#
# train loss: 0.000165899919091949
# Model saved
#
# train loss: 0.00016362085375797803
# Model saved
#
# train loss: 0.00016147016852245566
# Model saved
#
# train loss: 0.00015942589908485739
# Model saved
#
# train loss: 0.00015735688918413652
# Model saved
#
# train loss: 0.00015531745147843282
# Model saved
#
# train loss: 0.00015337069516372615
# Model saved
#
# train loss: 0.00015157572044494538
# Model saved
#
# train loss: 0.00014975027467649396
# Model saved
#
# train loss: 0.0001479732121998289
# Model saved
#
# train loss: 0.00014630069538076236
# Model saved
#
# train loss: 0.00014459962031751185
# Model saved
#
# train loss: 0.00014307114841423325
# Model saved
#
# train loss: 0.0001415236646608075
# Model saved
#
# train loss: 0.00014004647082811525
# Model saved
#
# train loss: 0.00013854892885370863
# Model saved
#
# train loss: 0.00013704720856641414
# Model saved
#
# train loss: 0.00013560269450450492
# Model saved
#
# train loss: 0.00013422457610132215
# Model saved
#
# train loss: 0.00013288917657825657
# Model saved
#
# train loss: 0.00013161178616852905
# Model saved
#
# train loss: 0.00013037592682202723
# Model saved
#
# train loss: 0.00012906642459658952
# Model saved
#
# train loss: 0.0001278222214816648
# Model saved
#
# train loss: 0.0001267123109394617
# Model saved
#
# train loss: 0.00012556838961827154
# Model saved
#
# train loss: 0.00012448851984152255
# Model saved
#
# train loss: 0.0001234317775882448
# Model saved
#
# train loss: 0.00012230883122713374
# Model saved
#
# train loss: 0.00012139858001699368
# Model saved
#
# train loss: 0.00012029001145021168
# Model saved
#
# train loss: 0.00011927233067147737
# Model saved
#
# train loss: 0.00011828251544924605
# Model saved
#
# train loss: 0.00011734133003462303
# Model saved
#
# train loss: 0.00011640506314151656
# Model saved
#
# train loss: 0.00011548572767435894
# Model saved
#
# train loss: 0.00011457869813901447
# Model saved
#
# train loss: 0.00011371497258662875
# Model saved
#
# train loss: 0.00011285362338226912
# Model saved
#
# train loss: 0.00011198180866584991
# Model saved
#
# train loss: 0.00011111418350166107
# Model saved
#
# train loss: 0.0001102888970795418
# Model saved
#
# train loss: 0.00010944373800166751
# Model saved
#
# train loss: 0.00010870346760374185
# Model saved
#
# train loss: 0.00010789285209988306
# Model saved
#
# train loss: 0.00010712696658402864
# Model saved
#
# train loss: 0.00010634026661245007
# Model saved
#
# train loss: 0.00010564903691789092
# Model saved
#
# train loss: 0.00010487817112383011
# Model saved

# %% [markdown]
# ## Model Testing

# %%
# Load the best model
model_ = torch.load(f'./result/Elec_trans_BILSTM_General.pt')

# %%
# Initial settings 
output_test = []
target_test = []

# Model Testing
with torch.no_grad():
    model_.eval()
    running_loss_t = 0.0
    
    for batch_idx, test_data in enumerate(test_dataloader):
        
        inputs_t = test_data[0].to(device).float()
        target_t = test_data[1].to(device).float()

        outputs_t = model_(inputs_t)
        
        output_test.append(outputs_t)
        target_test.append(target_t)
        
# Combine the tensors into one
combined_tensor_target = torch.cat(target_test, dim=0)
combined_tensor_pred = torch.cat(output_test, dim=0)

# Use only the last values of the window
last_values_target = combined_tensor_target[:, -1].cpu()
last_values_pred = combined_tensor_pred.cpu()

# Inverse transform using MinMaxScaler 
real_values = scaler_target.inverse_transform(last_values_target.numpy().reshape(-1, 1))
real_pred_values = scaler_target.inverse_transform(last_values_pred.numpy().reshape(-1, 1))

# %% [markdown]
# ## Model Performance Evaluation

# %%
# Calculate MSE
mse = mean_squared_error(real_values, real_pred_values)
print("Mean Squared Error:", mse)

# Calculate R² Score
r2 = r2_score(real_values, real_pred_values)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 0.04360778
# R² Score: 0.9796467286683732

# %%
# Compare the test results: Actual values vs Predicted values
plt.figure(figsize=(12, 6))
plt.plot(real_values, label='Actual', color='blue')
plt.plot(real_pred_values, label='Predicted', color='red', alpha=0.7)
plt.title('Actual vs Predicted')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.show()
