# %% [markdown]
# # Nitrogen Dioxide Levels Forecasting

# %% [markdown]
# ## Import Necessary Libraries

# %%
## Import necessary libraries
import pandas as pd
import numpy as np
import random 
from urllib.parse import quote, unquote
from datetime import timedelta
import matplotlib.pyplot as plt

## Import libraries for the model
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from tqdm.notebook import trange
from sklearn.metrics import mean_squared_error, r2_score

## Set path for saving model training results
import os
os.makedirs('./result', exist_ok=True)

## Set Cuda for computation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

## Set random seed
def set_seed(seed_val):
    random.seed(seed_val)
    np.random.seed(seed_val)
    torch.manual_seed(seed_val)
    torch.cuda.manual_seed_all(seed_val)

# Set seed
seed_val = 77
set_seed(seed_val)
# Out:
# cuda

# %% [markdown]
# ## Selecting Data Columns
# * Tag names are loaded in sequential order.
# * The process of selecting the required tag names from the tag name list.

# %%
# Function to display tag names
def show_column(URL):
    
    # Load tag name data
    df = pd.read_csv(URL)
    
    # Convert to list format
    df = df.values.reshape(-1)
    
    return df.tolist()

# %%
## Set parameters for displaying tag names
table = 'india_air_quality'

NAME_URL = f'http://127.0.0.1:5654/db/tql/datahub/api/v1/get-tag-names.tql?table={table}'

## Generate tag name list
name = show_column(NAME_URL)

# %%
name
# Out:
# ['AP001_AT (degree C)',
#  'AP001_BP (mmHg)',
#  'AP001_Benzene (ug/m3)',
#  'AP001_CO (mg/m3)',
#  'AP001_NH3 (ug/m3)',
#  'AP001_NO (ug/m3)',
#  'AP001_NO2 (ug/m3)',
#  'AP001_NOx (ppb)',
#  'AP001_Ozone (ug/m3)',
#  'AP001_PM10 (ug/m3)',
#  'AP001_PM2.5 (ug/m3)',
#  'AP001_RF (mm)',
#  'AP001_RH (%)',
#  'AP001_SO2 (ug/m3)',
#  'AP001_SR (W/mt2)',
#  'AP001_Temp (degree C)',
#  'AP001_Toluene (ug/m3)',
#  'AP001_VWS (m/s)',
#  'AP001_WD (deg)',
#  'AP001_WS (m/s)',
#  'AP001_Xylene (ug/m3)',
#  'AP002_AT (degree C)',
#  'AP002_BP (mmHg)',
#  'AP002_Benzene (ug/m3)',
#  'AP002_CO (mg/m3)',
#  'AP002_Eth-Benzene (ug/m3)',
#  'AP002_MP-Xylene (ug/m3)',
#  'AP002_NH3 (ug/m3)',
#  'AP002_NO (ug/m3)',
#  'AP002_NO2 (ug/m3)',
#  'AP002_NOx (ppb)',
#  'AP002_O Xylene (ug/m3)',
#  'AP002_Ozone (ug/m3)',
#  'AP002_PM10 (ug/m3)',
#  'AP002_PM2.5 (ug/m3)',
#  'AP002_RF (mm)',
#  'AP002_RH (%)',
#  'AP002_SO2 (ug/m3)',
#  'AP002_SR (W/mt2)',
#  'AP002_Toluene (ug/m3)',
#  'AP002_VWS (degree)',
#  'AP002_WD (deg)',
#  'AP002_WS (m/s)',
#  'AP003_AT (degree C)',
#  'AP003_BP (mmHg)',
#  'AP003_Benzene (ug/m3)',
#  'AP003_CO (mg/m3)',
#  'AP003_NH3 (ug/m3)',
#  'AP003_NO (ug/m3)',
#  'AP003_NO2 (ug/m3)',
#  'AP003_NOx (ppb)',
#  'AP003_Ozone (ug/m3)',
#  'AP003_PM10 (ug/m3)',
#  'AP003_PM2.5 (ug/m3)',
#  'AP003_RF (mm)',
#  'AP003_RH (%)',
#  'AP003_SO2 (ug/m3)',
#  'AP003_SR (W/mt2)',
#  'AP003_Temp (degree C)',
#  'AP003_Toluene (ug/m3)',
#  'AP003_VWS (m/s)',
#  'AP003_WD (degree)',
#  'AP003_WS (m/s)',
#  'AP003_Xylene (ug/m3)',
#  'AP004_AT (degree C)',
#  'AP004_BP (mmHg)',
#  'AP004_Benzene (ug/m3)',
#  'AP004_CO (mg/m3)',
#  'AP004_Eth-Benzene (ug/m3)',
#  'AP004_MP-Xylene (ug/m3)',
#  'AP004_NH3 (ug/m3)',
#  'AP004_NO (ug/m3)',
#  'AP004_NO2 (ug/m3)',
#  'AP004_NOx (ppb)',
#  'AP004_Ozone (ug/m3)',
#  'AP004_PM10 (ug/m3)',
#  'AP004_PM2.5 (ug/m3)',
#  'AP004_RF (mm)',
#  'AP004_RH (%)',
#  'AP004_SO2 (ug/m3)',
#  'AP004_SR (W/mt2)',
#  'AP004_Temp (degree C)',
#  'AP004_Toluene (ug/m3)',
#  'AP004_VWS (m/s)',
#  'AP004_WD (degree)',
#  'AP004_WS (m/s)',
#  'AP004_Xylene (ug/m3)',
#  'AP007_AT (degree C)',
#  'AP007_BP (mmHg)',
#  'AP007_Benzene (ug/m3)',
#  'AP007_CO (mg/m3)',
#  'AP007_Eth-Benzene (ug/m3)',
#  'AP007_MP-Xylene (ug/m3)',
#  'AP007_NH3 (ug/m3)',
#  'AP007_NO (ug/m3)',
#  'AP007_NO2 (ug/m3)',
#  'AP007_NOx (ppb)',
#  'AP007_O Xylene (ug/m3)',
#  'AP007_Ozone (ug/m3)',
#  'AP007_PM10 (ug/m3)',
#  'AP007_PM2.5 (ug/m3)',
#  'AP007_RF (mm)',
#  'AP007_RH (%)',
#  'AP007_SO2 (ug/m3)',
#  'AP007_SR (W/mt2)',
#  'AP007_Toluene (ug/m3)',
#  'AP007_VWS (m/s)',
#  'AP007_WD (degree)',
#  'AP007_WS (m/s)',
#  'AP008_AT (degree C)',
#  'AP008_BP (mmHg)',
#  'AP008_Benzene (ug/m3)',
#  'AP008_CO (mg/m3)',
#  'AP008_Eth-Benzene (ug/m3)',
#  'AP008_MP-Xylene (ug/m3)',
#  'AP008_NH3 (ug/m3)',
#  'AP008_NO (ug/m3)',
#  'AP008_NO2 (ug/m3)',
#  'AP008_NOx (ppb)',
#  'AP008_O Xylene (ug/m3)',
#  'AP008_Ozone (ug/m3)',
#  'AP008_PM10 (ug/m3)',
#  'AP008_PM2.5 (ug/m3)',
#  'AP008_RF (mm)',
#  'AP008_RH (%)',
#  'AP008_SO2 (ug/m3)',
#  'AP008_SR (W/mt2)',
#  'AP008_Toluene (ug/m3)',
#  'AP008_VWS (m/s)',
#  'AP008_WD (degree)',
#  'AP008_WS (m/s)',
#  'AS005_AT (degree C)',
#  'AS005_Benzene (ug/m3)',
#  'AS005_CO (mg/m3)',
#  'AS005_Eth-Benzene (ug/m3)',
#  'AS005_MP-Xylene (ug/m3)',
#  'AS005_NH3 (ug/m3)',
#  'AS005_NO (ug/m3)',
#  'AS005_NO2 (ug/m3)',
#  'AS005_NOx (ppb)',
#  'AS005_O Xylene (ug/m3)',
#  'AS005_Ozone (ug/m3)',
#  'AS005_PM10 (ug/m3)',
#  'AS005_PM2.5 (ug/m3)',
#  'AS005_RF (mm)',
#  'AS005_RH (%)',
#  'AS005_SO2 (ug/m3)',
#  'AS005_SR (W/mt2)',
#  'AS005_Temp (degree C)',
#  'AS005_Toluene (ug/m3)',
#  'AS005_WD (degree)',
#  'AS005_WS (m/s)',
#  'AS009_AT (degree C)',
#  'AS009_Benzene (ug/m3)',
#  'AS009_CO (mg/m3)',
#  'AS009_Eth-Benzene (ug/m3)',
#  'AS009_MP-Xylene (ug/m3)',
#  'AS009_NH3 (ug/m3)',
#  'AS009_NO (ug/m3)',
#  'AS009_NO2 (ug/m3)',
#  'AS009_NOx (ppb)',
#  'AS009_O Xylene (ug/m3)',
#  'AS009_Ozone (ug/m3)',
#  'AS009_PM10 (ug/m3)',
#  'AS009_PM2.5 (ug/m3)',
#  'AS009_RF (mm)',
#  'AS009_RH (%)',
#  'AS009_SO2 (ug/m3)',
#  'AS009_SR (W/mt2)',
#  'AS009_Toluene (ug/m3)',
#  'AS009_WD (degree)',
#  'AS009_WS (m/s)',
#  'BR001_AT (degree C)',
#  'BR001_BP (mmHg)',
#  'BR001_Benzene (ug/m3)',
#  'BR001_CO (mg/m3)',
#  'BR001_NO (ug/m3)',
#  'BR001_NO2 (ug/m3)',
#  'BR001_NOx (ppb)',
#  'BR001_Ozone (ug/m3)',
#  'BR001_PM2.5 (ug/m3)',
#  'BR001_RH (%)',
#  'BR001_SO2 (ug/m3)',
#  'BR001_SR (W/mt2)',
#  'BR001_Temp ()',
#  'BR001_Toluene (ug/m3)',
#  'BR001_VWS (m/s)',
#  'BR001_WD (deg)',
#  'BR001_WS (m/s)',
#  'BR001_Xylene (ug/m3)',
#  'BR002_AT (degree C)',
#  'BR002_BP (mmHg)',
#  'BR002_Benzene (ug/m3)',
#  'BR002_CO (mg/m3)',
#  'BR002_NO (ug/m3)',
#  'BR002_NO2 (ug/m3)',
#  'BR002_NOx (ppb)',
#  'BR002_Ozone (ug/m3)',
#  'BR002_PM2.5 (ug/m3)',
#  'BR002_RF (mm)',
#  'BR002_RH (%)',
#  'BR002_SO2 (ug/m3)',
#  'BR002_SR (W/mt2)',
#  'BR002_Temp (degree C)',
#  'BR002_Toluene (ug/m3)',
#  'BR002_VWS (m/s)',
#  'BR002_WD (deg)',
#  'BR002_WS (m/s)',
#  'BR002_Xylene (ug/m3)',
#  'BR003_AT (degree C)',
#  'BR003_BP (mmHg)',
#  'BR003_Benzene (ug/m3)',
#  'BR003_CO (mg/m3)',
#  'BR003_NO (ug/m3)',
#  'BR003_NO2 (ug/m3)',
#  'BR003_NOx (ppb)',
#  'BR003_Ozone (ug/m3)',
#  'BR003_PM2.5 (ug/m3)',
#  'BR003_RF (mm)',
#  'BR003_RH (%)',
#  'BR003_SO2 (ug/m3)',
#  'BR003_SR (W/mt2)',
#  'BR003_Toluene (ug/m3)',
#  'BR003_VWS (m/s)',
#  'BR003_WD (deg)',
#  'BR003_WS (m/s)',
#  'BR003_Xylene (ug/m3)',
#  'BR004_AT (degree C)',
#  'BR004_BP (mmHg)',
#  'BR004_Benzene (ug/m3)',
#  'BR004_CO (mg/m3)',
#  'BR004_Eth-Benzene (ug/m3)',
#  'BR004_MP-Xylene (ug/m3)',
#  'BR004_NH3 (ug/m3)',
#  'BR004_NO (ug/m3)',
#  'BR004_NO2 (ug/m3)',
#  'BR004_NOx (ppb)',
#  'BR004_Ozone (ug/m3)',
#  'BR004_PM10 (ug/m3)',
#  'BR004_PM2.5 (ug/m3)',
#  'BR004_RF (mm)',
#  'BR004_RH (%)',
#  'BR004_SO2 (ug/m3)',
#  'BR004_SR (W/mt2)',
#  'BR004_Toluene (ug/m3)',
#  'BR004_WD (degree)',
#  'BR004_WS (m/s)',
#  'BR004_Xylene (ug/m3)',
#  'BR005_AT (degree C)',
#  'BR005_BP (mmHg)',
#  'BR005_Benzene (ug/m3)',
#  'BR005_CO (mg/m3)',
#  'BR005_Eth-Benzene (ug/m3)',
#  'BR005_MP-Xylene (ug/m3)',
#  'BR005_NH3 (ug/m3)',
#  'BR005_NO (ug/m3)',
#  'BR005_NO2 (ug/m3)',
#  'BR005_NOx (ppb)',
#  'BR005_Ozone (ug/m3)',
#  'BR005_PM10 (ug/m3)',
#  'BR005_PM2.5 (ug/m3)',
#  'BR005_RF (mm)',
#  'BR005_RH (%)',
#  'BR005_SO2 (ug/m3)',
#  'BR005_SR (W/mt2)',
#  'BR005_Toluene (ug/m3)',
#  'BR005_WD (degree)',
#  'BR005_WS (m/s)',
#  'BR005_Xylene (ug/m3)',
#  'BR006_AT (degree C)',
#  'BR006_BP (mmHg)',
#  'BR006_Benzene (ug/m3)',
#  'BR006_CO (mg/m3)',
#  'BR006_Eth-Benzene (ug/m3)',
#  'BR006_MP-Xylene (ug/m3)',
#  'BR006_NH3 (ug/m3)',
#  'BR006_NO (ug/m3)',
#  'BR006_NO2 (ug/m3)',
#  'BR006_NOx (ppb)',
#  'BR006_Ozone (ug/m3)',
#  'BR006_PM10 (ug/m3)',
#  'BR006_PM2.5 (ug/m3)',
#  'BR006_RF (mm)',
#  'BR006_RH (%)',
#  'BR006_SO2 (ug/m3)',
#  'BR006_SR (W/mt2)',
#  'BR006_Toluene (ug/m3)',
#  'BR006_WD (degree)',
#  'BR006_WS (m/s)',
#  'BR006_Xylene (ug/m3)',
#  'BR007_AT (degree C)',
#  'BR007_BP (mmHg)',
#  'BR007_Benzene (ug/m3)',
#  'BR007_CO (mg/m3)',
#  'BR007_Eth-Benzene (ug/m3)',
#  'BR007_MP-Xylene (ug/m3)',
#  'BR007_NH3 (ug/m3)',
#  'BR007_NO (ug/m3)',
#  'BR007_NO2 (ug/m3)',
#  'BR007_NOx (ppb)',
#  'BR007_Ozone (ug/m3)',
#  'BR007_PM10 (ug/m3)',
#  'BR007_PM2.5 (ug/m3)',
#  'BR007_RF (mm)',
#  'BR007_RH (%)',
#  'BR007_SO2 (ug/m3)',
#  'BR007_SR (W/mt2)',
#  'BR007_Toluene (ug/m3)',
#  'BR007_WD (degree)',
#  'BR007_WS (m/s)',
#  'BR007_Xylene (ug/m3)',
#  'BR008_AT (degree C)',
#  'BR008_BP (mmHg)',
#  'BR008_Benzene (ug/m3)',
#  'BR008_CO (mg/m3)',
#  'BR008_Eth-Benzene (ug/m3)',
#  'BR008_MP-Xylene (ug/m3)',
#  'BR008_NH3 (ug/m3)',
#  'BR008_NO (ug/m3)',
#  'BR008_NO2 (ug/m3)',
#  'BR008_NOx (ppb)',
#  'BR008_Ozone (ug/m3)',
#  'BR008_PM10 (ug/m3)',
#  'BR008_PM2.5 (ug/m3)',
#  'BR008_RF ()',
#  'BR008_RH (%)',
#  'BR008_SO2 (ug/m3)',
#  'BR008_SR (W/mt2)',
#  'BR008_Toluene (ug/m3)',
#  'BR008_WD (degree)',
#  'BR008_WS (m/s)',
#  'BR008_Xylene (ug/m3)',
#  'BR009_AT (degree C)',
#  'BR009_BP (mmHg)',
#  'BR009_Benzene (ug/m3)',
#  'BR009_CO (mg/m3)',
#  'BR009_Eth-Benzene (ug/m3)',
#  'BR009_MP-Xylene (ug/m3)',
#  'BR009_NH3 (ug/m3)',
#  'BR009_NO (ug/m3)',
#  'BR009_NO2 (ug/m3)',
#  'BR009_NOx (ppb)',
#  'BR009_Ozone (ug/m3)',
#  'BR009_PM10 (ug/m3)',
#  'BR009_PM2.5 (ug/m3)',
#  'BR009_RF (mm)',
#  'BR009_RH (%)',
#  'BR009_SO2 (ug/m3)',
#  'BR009_SR (W/mt2)',
#  'BR009_Toluene (ug/m3)',
#  'BR009_WD (degree)',
#  'BR009_WS (m/s)',
#  'BR009_Xylene (ug/m3)',
#  'BR010_AT (degree C)',
#  'BR010_BP (mmHg)',
#  'BR010_Benzene (ug/m3)',
#  'BR010_CO (mg/m3)',
#  'BR010_Eth-Benzene (ug/m3)',
#  'BR010_MP-Xylene (ug/m3)',
#  'BR010_NH3 (ug/m3)',
#  'BR010_NO (ug/m3)',
#  'BR010_NO2 (ug/m3)',
#  'BR010_NOx (ppb)',
#  'BR010_Ozone (ug/m3)',
#  'BR010_PM10 (ug/m3)',
#  'BR010_PM2.5 (ug/m3)',
#  'BR010_RF (mm)',
#  'BR010_RH (%)',
#  'BR010_SO2 (ug/m3)',
#  'BR010_SR (W/mt2)',
#  'BR010_Toluene (ug/m3)',
#  'BR010_WD (degree)',
#  'BR010_WS (m/s)',
#  'BR010_Xylene (ug/m3)',
#  'BR011_AT (degree C)',
#  'BR011_BP (mmHg)',
#  'BR011_Benzene (ug/m3)',
#  'BR011_CO (mg/m3)',
#  'BR011_Eth-Benzene (ug/m3)',
#  'BR011_MP-Xylene (ug/m3)',
#  'BR011_NH3 (ug/m3)',
#  'BR011_NO (ug/m3)',
#  'BR011_NO2 (ug/m3)',
#  'BR011_NOx (ppb)',
#  'BR011_Ozone (ug/m3)',
#  'BR011_PM10 (ug/m3)',
#  'BR011_PM2.5 (ug/m3)',
#  'BR011_RF (mm)',
#  'BR011_RH (%)',
#  'BR011_SO2 (ug/m3)',
#  'BR011_SR (W/mt2)',
#  'BR011_Toluene (ug/m3)',
#  'BR011_WD (degree)',
#  'BR011_WS (m/s)',
#  'BR011_Xylene (ug/m3)',
#  'BR016_AT (degree C)',
#  'BR016_Benzene (ug/m3)',
#  'BR016_CO (mg/m3)',
#  'BR016_Eth-Benzene (ug/m3)',
#  'BR016_MP-Xylene (ug/m3)',
#  'BR016_NH3 (ug/m3)',
#  'BR016_NO (ug/m3)',
#  'BR016_NO2 (ug/m3)',
#  'BR016_NOx (ppb)',
#  'BR016_Ozone (ug/m3)',
#  'BR016_PM10 (ug/m3)',
#  'BR016_PM2.5 (ug/m3)',
#  'BR016_RF (mm)',
#  'BR016_RH (%)',
#  'BR016_SO2 (ug/m3)',
#  'BR016_SR (W/mt2)',
#  'BR016_Toluene (ug/m3)',
#  'BR016_WD (degree)',
#  'BR016_WS (m/s)',
#  'BR016_Xylene (ug/m3)',
#  'BR019_AT (degree C)',
#  'BR019_Benzene (ug/m3)',
#  'BR019_CO (mg/m3)',
#  'BR019_Eth-Benzene (ug/m3)',
#  'BR019_MP-Xylene (ug/m3)',
#  'BR019_NH3 (ug/m3)',
#  'BR019_NO (ug/m3)',
#  'BR019_NO2 (ug/m3)',
#  'BR019_NOx (ppb)',
#  'BR019_O Xylene (ug/m3)',
#  'BR019_Ozone (ug/m3)',
#  'BR019_PM10 (ug/m3)',
#  'BR019_PM2.5 (ug/m3)',
#  'BR019_RF (mm)',
#  'BR019_RH (%)',
#  'BR019_SO2 (ug/m3)',
#  'BR019_SR (W/mt2)',
#  'BR019_Toluene (ug/m3)',
#  'BR019_WD (degree)',
#  'BR019_WS (m/s)',
#  'BR019_Xylene (ug/m3)',
#  'CG001_AT (degree C)',
#  'CG001_BP (mmHg)',
#  'CG001_CO (mg/m3)',
#  'CG001_NO (ug/m3)',
#  'CG001_NO2 (ug/m3)',
#  'CG001_NOx (ppb)',
#  'CG001_PM10 (ug/m3)',
#  'CG001_PM2.5 (ug/m3)',
#  'CG001_RF (mm)',
#  'CG001_RH (%)',
#  'CG001_SO2 (ug/m3)',
#  'CG001_SR (W/mt2)',
#  'CG001_WD (degree)',
#  'CG001_WS (m/s)',
#  'CG003_AT (degree C)',
#  'CG003_Benzene (ug/m3)',
#  'CG003_CO (mg/Nm3)',
#  'CG003_NH3 (ug/m3)',
#  'CG003_NO (ug/m3)',
#  'CG003_NO2 (ug/m3)',
#  'CG003_NOx (ppb)',
#  'CG003_Ozone (ug/m3)',
#  'CG003_PM10 (ug/m3)',
#  'CG003_PM2.5 (ug/m3)',
#  'CG003_RF (mm)',
#  'CG003_RH (%)',
#  'CG003_SO2 (ug/m3)',
#  'CG003_SR (W/mt2)',
#  'CG003_WD (degree)',
#  'CG003_WS (m/s)',
#  'CG004_AT (degree C)',
#  'CG004_Benzene (ug/m3)',
#  'CG004_CO (mg/m3)',
#  'CG004_NH3 (ug/m3)',
#  'CG004_NO (ug/m3)',
#  'CG004_NO2 (ug/m3)',
#  'CG004_NOx (ppb)',
#  'CG004_Ozone (ug/m3)',
#  'CG004_PM10 (ug/m3)',
#  'CG004_PM2.5 (ug/m3)',
#  'CG004_RF (mm)',
#  'CG004_RH (%)',
#  'CG004_SO2 (ug/m3)',
#  'CG004_SR (W/mt2)',
#  'CG004_WD (degree)',
#  'CG004_WS (m/s)',
#  'CG005_AT (degree C)',
#  'CG005_Benzene (ug/m3)',
#  'CG005_CO (mg/m3)',
#  'CG005_NH3 (ug/m3)',
#  'CG005_NO (ug/m3)',
#  'CG005_NO2 (ug/m3)',
#  'CG005_NOx (ppb)',
#  'CG005_Ozone (ug/m3)',
#  'CG005_PM10 (ug/m3)',
#  'CG005_PM2.5 (ug/m3)',
#  'CG005_RF (mm)',
#  'CG005_RH (%)',
#  'CG005_SO2 (ug/m3)',
#  'CG005_SR (W/mt2)',
#  'CG005_WD (degree)',
#  'CG005_WS (m/s)',
#  'CG006_AT (degree C)',
#  'CG006_Benzene (ug/m3)',
#  'CG006_CO (mg/m3)',
#  'CG006_NH3 (ug/m3)',
#  'CG006_NO (ug/m3)',
#  'CG006_NO2 (ug/m3)',
#  'CG006_NOx (ppb)',
#  'CG006_Ozone (ug/m3)',
#  'CG006_PM10 (ug/m3)',
#  'CG006_PM2.5 (ug/m3)',
#  'CG006_RF (mm)',
#  'CG006_RH (%)',
#  'CG006_SO2 (ug/m3)',
#  'CG006_SR (W/mt2)',
#  'CG006_WD (degree)',
#  'CG006_WS (m/s)',
#  'CG007_AT (degree C)',
#  'CG007_Benzene (ug/m3)',
#  'CG007_CO (mg/m3)',
#  'CG007_NH3 (ug/m3)',
#  'CG007_NO (ug/m3)',
#  'CG007_NO2 (ug/m3)',
#  'CG007_NOx (ppb)',
#  'CG007_Ozone (ug/m3)',
#  'CG007_PM10 (ug/m3)',
#  'CG007_PM2.5 (ug/m3)',
#  'CG007_RF (mm)',
#  'CG007_RH (%)',
#  'CG007_SO2 (ug/m3)',
#  'CG007_SR (W/mt2)',
#  'CG007_WD (degree)',
#  'CG007_WS (m/s)',
#  'CG008_AT (degree C)',
#  'CG008_Benzene (ug/m3)',
#  'CG008_CO (mg/m3)',
#  'CG008_NH3 (ug/m3)',
#  'CG008_NO (ug/m3)',
#  'CG008_NO2 (ug/m3)',
#  'CG008_NOx (ppb)',
#  'CG008_Ozone (ug/m3)',
#  'CG008_PM10 (ug/m3)',
#  'CG008_PM2.5 (ug/m3)',
#  'CG008_RF (mm)',
#  'CG008_RH (%)',
#  'CG008_SO2 (ug/m3)',
#  'CG008_SR (W/mt2)',
#  'CG008_WD (degree)',
#  'CG008_WS (m/s)',
#  'CG009_AT (degree C)',
#  'CG009_Benzene (ug/m3)',
#  'CG009_CO (mg/m3)',
#  'CG009_NH3 (ug/m3)',
#  'CG009_NO (ug/m3)',
#  'CG009_NO2 (ug/m3)',
#  'CG009_NOx (ppb)',
#  'CG009_Ozone (ug/m3)',
#  'CG009_PM10 (ug/m3)',
#  'CG009_PM2.5 (ug/m3)',
#  'CG009_RF (mm)',
#  'CG009_RH (%)',
#  'CG009_SO2 (ug/m3)',
#  'CG009_SR (W/mt2)',
#  'CG009_WD (degree)',
#  'CG009_WS (m/s)',
#  'CG010_AT (degree C)',
#  'CG010_Benzene (ug/m3)',
#  'CG010_CO (mg/m3)',
#  'CG010_NH3 (ug/m3)',
#  'CG010_NO (ug/m3)',
#  'CG010_NO2 (ug/m3)',
#  'CG010_NOx (ppb)',
#  'CG010_Ozone (ug/m3)',
#  'CG010_PM10 (ug/m3)',
#  'CG010_PM2.5 (ug/m3)',
#  'CG010_RF (mm)',
#  'CG010_RH (%)',
#  'CG010_SO2 (ug/m3)',
#  'CG010_SR (W/mt2)',
#  'CG010_WD (degree)',
#  'CG010_WS (m/s)',
#  'CG011_AT (degree C)',
#  'CG011_Benzene (ug/m3)',
#  'CG011_CO (mg/m3)',
#  'CG011_NH3 (ug/m3)',
#  'CG011_NO (ug/m3)',
#  'CG011_NO2 (ug/m3)',
#  'CG011_NOx (ppb)',
#  'CG011_Ozone (ug/m3)',
#  'CG011_PM10 (ug/m3)',
#  'CG011_PM2.5 (ug/m3)',
#  'CG011_RF (m/s)',
#  'CG011_RH (%)',
#  'CG011_SO2 (ug/m3)',
#  'CG011_SR (W/mt2)',
#  'CG011_WD (degree)',
#  'CG011_WS (m/s)',
#  'CG012_AT (degree C)',
#  'CG012_Benzene (ug/m3)',
#  'CG012_CO (mg/m3)',
#  'CG012_NH3 (ug/m3)',
#  'CG012_NO (ug/m3)',
#  'CG012_NO2 (ug/m3)',
#  'CG012_NOx (ppb)',
#  'CG012_Ozone (ug/m3)',
#  'CG012_PM10 (ug/m3)',
#  'CG012_PM2.5 (ug/m3)',
#  'CG012_RF (mm)',
#  'CG012_RH (%)',
#  'CG012_SO2 (ug/m3)',
#  'CG012_SR (W/mt2)',
#  'CG012_WD (degree)',
#  'CG012_WS (m/s)',
#  'CG013_AT (degree C)',
#  'CG013_Benzene (ug/m3)',
#  'CG013_CO (mg/m3)',
#  'CG013_NH3 (ug/m3)',
#  'CG013_NO (ug/m3)',
#  'CG013_NO2 (ug/m3)',
#  'CG013_NOx (ppb)',
#  'CG013_Ozone (ug/m3)',
#  'CG013_PM10 (ug/m3)',
#  'CG013_PM2.5 (ug/m3)',
#  'CG013_RF (mm)',
#  'CG013_RH (%)',
#  'CG013_SO2 (ug/m3)',
#  'CG013_SR (W/mt2)',
#  'CG013_WD (degree)',
#  'CG013_WS (m/s)',
#  'CG014_AT (degree C)',
#  'CG014_Benzene (ug/m3)',
#  'CG014_CO (mg/m3)',
#  'CG014_NH3 (ug/m3)',
#  'CG014_NO (ug/m3)',
#  'CG014_NO2 (ug/m3)',
#  'CG014_NOx (ppb)',
#  'CG014_Ozone (ug/m3)',
#  'CG014_PM10 (ug/m3)',
#  'CG014_PM2.5 (ug/m3)',
#  'CG014_RF (mm)',
#  'CG014_RH (%)',
#  'CG014_SO2 (ug/m3)',
#  'CG014_SR (ug/m3)',
#  'CG014_WD (degree)',
#  'CG014_WS (m/s)',
#  'DL001_Benzene (ug/m3)',
#  'DL001_CO (mg/m3)',
#  'DL001_NH3 (ug/m3)',
#  'DL001_NO (ug/m3)',
#  'DL001_NO2 (ug/m3)',
#  'DL001_NOx (ppb)',
#  'DL001_Ozone (ug/m3)',
#  'DL001_PM10 (ug/m3)',
#  'DL001_PM2.5 (ug/m3)',
#  'DL001_SO2 (ug/m3)',
#  'DL012_AT (degree C)',
#  'DL012_BP (mmHg)',
#  'DL012_Benzene (ug/m3)',
#  'DL012_CO (mg/m3)',
#  'DL012_NH3 (ug/m3)',
#  'DL012_NO (ug/m3)',
#  'DL012_NO2 (ug/m3)',
#  'DL012_NOx (ppb)',
#  'DL012_Ozone (ug/m3)',
#  'DL012_PM10 (ug/m3)',
#  'DL012_PM2.5 (ug/m3)',
#  'DL012_RF (mm)',
#  'DL012_RH (%)',
#  'DL012_SO2 (ug/m3)',
#  'DL012_SR (W/mt2)',
#  'DL012_Temp (degree C)',
#  'DL012_Toluene (ug/m3)',
#  'DL012_VWS (m/s)',
#  'DL012_WD (deg)',
#  'DL012_WS ()',
#  'DL012_Xylene (ug/m3)',
#  'DL015_AT (degree C)',
#  'DL015_BP (mmHg)',
#  'DL015_Benzene (ug/m3)',
#  'DL015_CO (mg/m3)',
#  'DL015_NH3 (ug/m3)',
#  'DL015_NO (ug/m3)',
#  'DL015_NO2 (ug/m3)',
#  'DL015_NOx (ppb)',
#  'DL015_Ozone (ug/m3)',
#  'DL015_PM10 (ug/m3)',
#  'DL015_PM2.5 (ug/m3)',
#  'DL015_RF (mm)',
#  'DL015_RH (%)',
#  'DL015_SO2 (ug/m3)',
#  'DL015_SR (W/mt2)',
#  'DL015_Temp (degree C)',
#  'DL015_Toluene (ug/m3)',
#  'DL015_WD (deg)',
#  'DL015_WS (m/s)',
#  'DL040_AT (degree C)',
#  'DL040_BP (mmHg)',
#  'DL040_Benzene (ug/m3)',
#  'DL040_CO (mg/m3)',
#  'DL040_Eth-Benzene (ug/m3)',
#  'DL040_MP-Xylene (ug/m3)',
#  'DL040_NH3 (ug/m3)',
#  'DL040_NO (ug/m3)',
#  'DL040_NO2 (ug/m3)',
#  'DL040_NOx (ppb)',
#  'DL040_Ozone (ug/m3)',
#  'DL040_PM10 (ug/m3)',
#  'DL040_PM2.5 (ug/m3)',
#  'DL040_RF (mm)',
#  'DL040_RH (%)',
#  'DL040_SO2 (ug/m3)',
#  'DL040_Toluene (ug/m3)',
#  'DL040_WD (degree)',
#  'DL040_WS (m/s)',
#  'DL040_Xylene (ug/m3)',
#  'GJ017_AT (degree C)',
#  'GJ017_BP (mmHg)',
#  'GJ017_CO (mg/m3)',
#  'GJ017_NO (ug/m3)',
#  'GJ017_NO2 (ug/m3)',
#  'GJ017_NOx (ppb)',
#  'GJ017_PM10 (ug/m3)',
#  'GJ017_PM2.5 (ug/m3)',
#  'GJ017_RF (mm)',
#  'GJ017_RH (%)',
#  'GJ017_SO2 (ug/m3)',
#  'GJ017_SR (W/mt2)',
#  'GJ017_WD (degree)',
#  'GJ017_WS (m/s)',
#  'HR001_AT (degree C)',
#  'HR001_BP (mmHg)',
#  'HR001_Benzene (ug/m3)',
#  'HR001_CO (mg/m3)',
#  'HR001_NO (ug/m3)',
#  'HR001_NO2 (ug/m3)',
#  'HR001_NOx (ppb)',
#  'HR001_Ozone (ug/m3)',
#  'HR001_PM2.5 (ug/m3)',
#  'HR001_RF (mm)',
#  'HR001_RH (%)',
#  'HR001_SO2 (ug/m3)',
#  'HR001_SR (W/mt2)',
#  'HR001_Temp (degree C)',
#  'HR001_Toluene (ug/m3)',
#  'HR001_VWS (m/s)',
#  'HR001_WD (deg)',
#  'HR001_WS (m/s)',
#  'HR001_Xylene (ug/m3)',
#  'HR002_AT (degree C)',
#  'HR002_BP (mmHg)',
#  'HR002_BP (mmHg).1',
#  'HR002_BP (mmHg).2',
#  'HR002_BP (mmHg).3',
#  'HR002_BP (mmHg).4',
#  'HR002_BP (mmHg).5',
#  'HR002_BP (mmHg).6',
#  'HR002_BP (mmHg).7',
#  'HR002_Benzene (ug/m3)',
#  'HR002_CO (mg/m3)',
#  'HR002_Eth-Benzene (ug/m3)',
#  'HR002_MP-Xylene (ug/m3)',
#  'HR002_NO (ug/m3)',
#  'HR002_NO2 (ug/m3)',
#  'HR002_NOx (ppb)',
#  'HR002_O Xylene (ug/m3)',
#  'HR002_Ozone (ug/m3)',
#  'HR002_PM2.5 (ug/m3)',
#  'HR002_RF (mm)',
#  'HR002_RF (mm).1',
#  'HR002_RF (mm).2',
#  'HR002_RF (mm).3',
#  'HR002_RF (mm).4',
#  'HR002_RF (mm).5',
#  'HR002_RF (mm).6',
#  'HR002_RF (mm).7',
#  'HR002_RH (%)',
#  'HR002_SO2 (ug/m3)',
#  'HR002_SR (W/mt2)',
#  'HR002_Temp (degree C)',
#  'HR002_Toluene (ug/m3)',
#  'HR002_VWS (m/s)',
#  'HR002_WD (deg)',
#  'HR002_WS (m/s)',
#  'HR002_Xylene ()',
#  'HR004_BP (mmHg)',
#  'HR004_Benzene (ug/m3)',
#  'HR004_CO (mg/m3)',
#  'HR004_Eth-Benzene (ug/m3)',
#  'HR004_MP-Xylene (ug/m3)',
#  'HR004_NO (ug/m3)',
#  'HR004_NO2 (ug/m3)',
#  'HR004_NOx (ppb)',
#  'HR004_O Xylene (ug/m3)',
#  'HR004_Ozone (ug/m3)',
#  'HR004_PM10 (ug/m3)',
#  'HR004_PM2.5 (ug/m3)',
#  'HR004_RF (mm)',
#  'HR004_RH (%)',
#  'HR004_SO2 (ug/m3)',
#  'HR004_SR (W/mt2)',
#  'HR004_Temp (degree C)',
#  'HR004_Toluene (ug/m3)',
#  'HR004_VWS (m/s)',
#  'HR004_WD (deg)',
#  'HR004_WS (m/s)',
#  'HR016_AT (degree C)',
#  'HR016_Benzene (ug/m3)',
#  'HR016_CO (mg/m3)',
#  'HR016_Eth-Benzene (ug/m3)',
#  'HR016_MP-Xylene (ug/m3)',
#  'HR016_NH3 (ug/m3)',
#  'HR016_NO (ug/m3)',
#  'HR016_NO2 (ug/m3)',
#  'HR016_NOx (ppb)',
#  'HR016_Ozone (ug/m3)',
#  'HR016_PM10 (ug/m3)',
#  'HR016_PM2.5 (ug/m3)',
#  'HR016_RF (mm)',
#  'HR016_RH (%)',
#  'HR016_SO2 (ug/m3)',
#  'HR016_SR (W/mt2)',
#  'HR016_Toluene (ug/m3)',
#  'HR016_WD (degree)',
#  'HR016_WS (m/s)',
#  'HR016_Xylene (ug/m3)',
#  'HR019_AT (degree C)',
#  'HR019_Benzene (ug/m3)',
#  'HR019_CO (mg/m3)',
#  'HR019_Eth-Benzene (ug/m3)',
#  'HR019_MP-Xylene (ug/m3)',
#  'HR019_NH3 (ug/m3)',
#  'HR019_NO (ug/m3)',
#  'HR019_NO2 (ug/m3)',
#  'HR019_NOx (ppb)',
#  'HR019_Ozone (ug/m3)',
#  'HR019_PM10 (ug/m3)',
#  'HR019_PM2.5 (ug/m3)',
#  'HR019_RF (mm)',
#  'HR019_RH (%)',
#  'HR019_SO2 (ug/m3)',
#  'HR019_SR (W/mt2)',
#  'HR019_Toluene (ug/m3)',
#  'HR019_WD (degree)',
#  'HR019_WS (m/s)',
#  'HR019_Xylene (ug/m3)',
#  'HR020_AT (degree C)',
#  'HR020_Benzene (ug/m3)',
#  'HR020_CO (mg/m3)',
#  'HR020_Eth-Benzene (ug/m3)',
#  'HR020_MP-Xylene (ug/m3)',
#  'HR020_NH3 (ug/m3)',
#  'HR020_NO (ug/m3)',
#  'HR020_NO2 (ug/m3)',
#  'HR020_NOx (ppb)',
#  'HR020_Ozone (ug/m3)',
#  'HR020_PM10 (ug/m3)',
#  'HR020_PM2.5 (ug/m3)',
#  'HR020_RF (mm)',
#  'HR020_RF (mm).1',
#  'HR020_RF (mm).2',
#  'HR020_RF (mm).3',
#  'HR020_RF (mm).4',
#  'HR020_RF (mm).5',
#  'HR020_RF (mm).6',
#  'HR020_RF (mm).7',
#  'HR020_SO2 (ug/m3)',
#  'HR020_SR (W/mt2)',
#  'HR020_Toluene (ug/m3)',
#  'HR020_WD (degree)',
#  'HR020_WS (m/s)',
#  'HR020_Xylene (ug/m3)',
#  'HR025_AT (degree C)',
#  'HR025_Benzene (ug/m3)',
#  'HR025_CO (mg/m3)',
#  'HR025_Eth-Benzene (ug/m3)',
#  'HR025_MP-Xylene (ug/m3)',
#  'HR025_NH3 (ug/m3)',
#  'HR025_NO (ug/m3)',
#  'HR025_NO2 (ug/m3)',
#  'HR025_NOx (ppb)',
#  'HR025_Ozone (ug/m3)',
#  'HR025_PM10 (ug/m3)',
#  'HR025_PM2.5 (ug/m3)',
#  'HR025_RF (mm)',
#  'HR025_RH (%)',
#  'HR025_SO2 (ug/m3)',
#  'HR025_SR (W/mt2)',
#  'HR025_Toluene (ug/m3)',
#  'HR025_WD (degree)',
#  'HR025_WS (m/s)',
#  'HR025_Xylene (ug/m3)',
#  'HR026_AT (degree C)',
#  'HR026_Benzene (ug/m3)',
#  'HR026_CO (mg/m3)',
#  'HR026_Eth-Benzene (ug/m3)',
#  'HR026_MP-Xylene (ug/m3)',
#  'HR026_NH3 (ug/m3)',
#  'HR026_NO (ug/m3)',
#  'HR026_NO2 (ug/m3)',
#  'HR026_NOx (ppb)',
#  'HR026_Ozone (ug/m3)',
#  'HR026_PM10 (ug/m3)',
#  'HR026_PM2.5 (ug/m3)',
#  'HR026_RF (mm)',
#  'HR026_RH (%)',
#  'HR026_SO2 (ug/m3)',
#  'HR026_SR (W/mt2)',
#  'HR026_Toluene (ug/m3)',
#  'HR026_WD (degree)',
#  'HR026_WS (m/s)',
#  'HR026_Xylene (ug/m3)',
#  'HR027_AT (degree C)',
#  'HR027_Benzene (ug/m3)',
#  'HR027_CO (mg/m3)',
#  'HR027_Eth-Benzene (ug/m3)',
#  'HR027_MP-Xylene (ug/m3)',
#  'HR027_NH3 (ug/m3)',
#  'HR027_NO (ug/m3)',
#  'HR027_NO2 (ug/m3)',
#  'HR027_NOx (ppb)',
#  'HR027_Ozone (ug/m3)',
#  'HR027_PM10 (ug/m3)',
#  'HR027_PM2.5 (ug/m3)',
#  'HR027_RF (mm)',
#  'HR027_RH (%)',
#  'HR027_SO2 (ug/m3)',
#  'HR027_SR (W/mt2)',
#  'HR027_Toluene (ug/m3)',
#  'HR027_WD (degree)',
#  'HR027_WS (m/s)',
#  'HR027_Xylene (ug/m3)',
#  'HR028_AT (degree C)',
#  'HR028_Benzene (ug/m3)',
#  'HR028_CO (mg/m3)',
#  'HR028_Eth-Benzene (ug/m3)',
#  'HR028_MP-Xylene (ug/m3)',
#  'HR028_NH3 (ug/m3)',
#  'HR028_NO (ug/m3)',
#  'HR028_NO2 (ug/m3)',
#  'HR028_NOx (ppb)',
#  'HR028_Ozone (ug/m3)',
#  'HR028_PM10 (ug/m3)',
#  'HR028_PM2.5 (ug/m3)',
#  'HR028_RF (mm)',
#  'HR028_RH (%)',
#  'HR028_SO2 (ug/m3)',
#  'HR028_SR (W/mt2)',
#  'HR028_Toluene (ug/m3)',
#  'HR028_WD (degree)',
#  'HR028_WS (m/s)',
#  'HR028_Xylene (ug/m3)',
#  'HR029_AT (degree C)',
#  'HR029_Benzene (ug/m3)',
#  'HR029_CO (mg/m3)',
#  'HR029_Eth-Benzene (ug/m3)',
#  'HR029_MP-Xylene (ug/m3)',
#  'HR029_NH3 (ug/m3)',
#  'HR029_NO (ug/m3)',
#  'HR029_NO2 (ug/m3)',
#  'HR029_NOx (ppb)',
#  'HR029_Ozone (ug/m3)',
#  'HR029_PM10 (ug/m3)',
#  'HR029_PM2.5 (ug/m3)',
#  'HR029_RF (mm)',
#  'HR029_RH (%)',
#  'HR029_SO2 (ug/m3)',
#  'HR029_SR (W/mt2)',
#  'HR029_Toluene (ug/m3)',
#  'HR029_WD (degree)',
#  'HR029_WS (m/s)',
#  'HR029_Xylene (ug/m3)',
#  'JH002_CO (mg/m3)',
#  'JH002_NO (ug/m3)',
#  'JH002_NO2 (ug/m3)',
#  'JH002_NOx (ppb)',
#  'JH002_Ozone (ug/m3)',
#  'JH002_PM10 (ug/m3)',
#  'JH002_PM2.5 (ug/m3)',
#  'JH002_SO2 (ug/m3)',
#  'KA002_AT (degree C)',
#  'KA002_BP (mmHg)',
#  'KA002_Benzene (ug/m3)',
#  'KA002_CO (mg/m3)',
#  'KA002_Eth-Benzene (ug/m3)',
#  'KA002_MP-Xylene (ug/m3)',
#  'KA002_NH3 (ug/m3)',
#  'KA002_NO (ug/m3)',
#  'KA002_NO2 (ug/m3)',
#  'KA002_NOx (ppb)',
#  'KA002_O Xylene (ug/m3)',
#  'KA002_Ozone (ug/m3)',
#  'KA002_PM10 (ug/m3)',
#  'KA002_PM2.5 (ug/m3)',
#  'KA002_RH (%)',
#  'KA002_SO2 (ug/m3)',
#  'KA002_SR (W/mt2)',
#  'KA002_Toluene (ug/m3)',
#  'KA002_VWS (m/s)',
#  'KA002_WD (deg)',
#  'KA002_WS (m/s)',
#  'KA004_CO (mg/m3)',
#  'KA004_NH3 (ug/m3)',
#  'KA004_NO (ug/m3)',
#  ...]

# %% [markdown]
# ## Converting TAG Name Format
# * After checking all the Tag Names from the India Air Quality dataset in the previous step, extract only the columns to be used and convert them into parameter format.
# * Use tag names AP001.

# %%
# Set the desired tag names
tags = name[:21]

# Wrap each item in the list with single quotes and separate with commas
tags_ = ",".join(f"'{tag}'" for tag in tags)

# Check the selected tag names
print(tags_)
# Out:
# 'AP001_AT (degree C)','AP001_BP (mmHg)','AP001_Benzene (ug/m3)','AP001_CO (mg/m3)','AP001_NH3 (ug/m3)','AP001_NO (ug/m3)','AP001_NO2 (ug/m3)','AP001_NOx (ppb)','AP001_Ozone (ug/m3)','AP001_PM10 (ug/m3)','AP001_PM2.5 (ug/m3)','AP001_RF (mm)','AP001_RH (%)','AP001_SO2 (ug/m3)','AP001_SR (W/mt2)','AP001_Temp (degree C)','AP001_Toluene (ug/m3)','AP001_VWS (m/s)','AP001_WD (deg)','AP001_WS (m/s)','AP001_Xylene (ug/m3)'

# %% [markdown]
# ## Load India Air Quality Dataset
# * Load the data using tag names

# %%
# Data loading function
def data_load(table, name, start_time, end_time, timeformat):
    
    # Load data 
    df = pd.read_csv(f'http://127.0.0.1:5654/db/tql/datahub/api/v1/select-rawdata.tql?table={table}&name={name}&start={start_time}&end={end_time}&timeformat={timeformat}')

    # Convert to data grouped by the time
    df = df.pivot_table(index='TIME', columns='NAME', values='VALUE', aggfunc='first').reset_index()

    # Set TIME column
    df['TIME'] = pd.to_datetime(df['TIME'])
    
    # Set time index
    df.set_index('TIME', inplace=True)
    
    # Move 'value' column to the end
    df['AP001_NO2 (ug/m3)'] = df.pop('AP001_NO2 (ug/m3)')
        
    return df

# %%
# Data time loading function
def time_data_load(table, name, start_time, end_time, timeformat):
    
    target = 'TIME'
    
    # Load the data
    df = pd.read_csv(f"http://127.0.0.1:5654/db/tql/datahub/api/v1/select-rawdata.tql?target={target}&table={table}&name={name}&start={start_time}&end={end_time}&timeformat={timeformat}")
    
    # Create a dummy value column for resampling
    df['value'] = 0
    
    # Perform resampling
    df['TIME'] = pd.to_datetime(df['TIME'])
    df.set_index('TIME', inplace=True)
    # Determine resampling units based on the data and perform resampling
    df = df.resample('1H').mean()
    
    # Remove missing values
    df = df.dropna()
    
    # Remove the dummy value column
    df = df.drop(['value'], axis=1)
    
    return df

# %%
# Time update function
# Update start and end times based on batch size
def update_time(time_df, start_time, batch_size, forecast_period):
    
    # Calculate how many data points need to be loaded
    time = batch_size + forecast_period - 1
    
    # Check the index number of the current time
    # If not found, set to the first index as there is no data for the current time
    try:
        index_now = time_df.index.get_loc(start_time)
    except KeyError:
        index_now = 0
    
    # Set the end time for the batch data based on the current time 
    end_time_ = str(time_df.index[index_now + time] + timedelta(seconds=1))
    
    # Set the index number for the next start time
    index_next = index_now + time - forecast_period + 1
    
    # Set the next start time
    next_start_time_ = str(time_df.index[index_next])
    
    # URL encoding
    start_time_ = quote(start_time)
    end_time_ = quote(end_time_)
    next_start_time_ = quote(next_start_time_)
    
    return start_time_, end_time_, next_start_time_, index_next

# %%
# Function to calculate the maximum and minimum values for selected tag names
def set_minmax_value(table, name, start_time_train, end_time_train):
    
    # URL encoding
    start = quote(start_time_train)
    end = quote(end_time_train)
    
    # Load Min, Max data
    df_ = pd.read_csv(f'http://127.0.0.1:5654/db/tql/datahub/api/v1/select-scale.tql?table={table}&name={name}&start={start}&end={end}')
    
    # Set Min, Max values
    Min = df_.iloc[:,1:-1].T
    Max = df_.iloc[:,2:].T
    
    return Min, Max

# %% [markdown]
# ## Data Preprocessing
#
# * 1 MinMax Scaling

# %% [markdown]
# ### 1. Min-Max Scaling Setup
# * Set up a Min-Max Scaler that uses the maximum and minimum values, as the entire dataset is not loaded due to the process concept.

# %%
# Definition of the MinMaxScaler class
class MinMaxScaler_custom:
    def __init__(self):
        self.min_ = None
        self.max_ = None

    # Set scale values based on the specified parameters
    def transform(self, X, min_values, max_values):
        X = np.array(X)
        self.min_ = np.array(min_values)
        self.max_ = np.array(max_values)
        
        if self.min_ is None or self.max_ is None:
            raise ValueError("Min and Max values are not set.")
        
        scale = (self.max_ - self.min_)
        if np.any(scale == 0):
            raise ValueError("Min and Max values are the same, resulting in a scale of 0.")
        
        return (X - self.min_) / scale
    
    # Normalize data based on calculated scale values
    def fit_transform(self, X, min_values, max_values):
        """Set parameters and then transform X"""
        return self.transform(X, min_values, max_values)

    # Inverse the normalized data back to original values
    def inverse_transform(self, X_scaled):
        """Inverse the transformation and return original values"""
        if self.min_ is None or self.max_ is None:
            raise ValueError("Min and Max values are not set.")
        
        X_scaled = np.array(X_scaled)
        scale = (self.max_ - self.min_)
        
        return X_scaled * scale + self.min_

# %% [markdown]
# ## Model Configuration
# * Using Temporal Convolutional Network(TCN) model.

# %%
class TemporalBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, dilation, dropout=0.2):
        super(TemporalBlock, self).__init__()
        padding = (kernel_size - 1) * dilation  # Set padding based on kernel size and dilation
        # First 1D convolution layer
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size, stride=stride, padding=padding, dilation=dilation)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)
        
        # Second 1D convolution layer
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size, stride=stride, padding=padding, dilation=dilation)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)
        
        # Construct the sequence of layers
        self.net = nn.Sequential(self.conv1, self.relu1, self.dropout1, self.conv2, self.relu2, self.dropout2)
        
        # Downsample for residual connection if needed
        self.downsample = nn.Conv1d(in_channels, out_channels, 1) if in_channels != out_channels else None
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.net(x)
        # Trim the output to match the input size (fixing size mismatch due to padding)
        out = out[:, :, :x.size(2)]
        res = x if self.downsample is None else self.downsample(x)
        return self.relu(out + res)

class TCN(nn.Module):
    def __init__(self, num_inputs, num_channels, kernel_size=2, dropout=0.2):
        super(TCN, self).__init__()
        layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            in_channels = num_inputs if i == 0 else num_channels[i-1]
            out_channels = num_channels[i]
            layers += [TemporalBlock(in_channels, out_channels, kernel_size, stride=1, dilation=dilation_size, 
                                     dropout=dropout)]
        self.network = nn.Sequential(*layers)
        self.linear = nn.Linear(num_channels[-1], 1)  # Output layer for regression tasks

    def forward(self, x):
        x = self.network(x)
        x = x[:, :, -1]  # Use the output from the last time step
        return self.linear(x)

# %%
# Model configuration parameters
input_channels = 20
hidden_channels = [25, 50, 75, 100] 
kernel_size = 3
dropout = 0.2

# Learning rate
learning_rate = 0.001

# Initialize the model, loss, and optimizer
model = TCN(num_inputs=input_channels, num_channels=hidden_channels, kernel_size=kernel_size, dropout=dropout).to(device)

# Configure loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Check the model architecture
print(model)
# Out:
# TCN(
#   (network): Sequential(
#     (0): TemporalBlock(
#       (conv1): Conv1d(20, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(25, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(20, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(25, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(20, 25, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#     (1): TemporalBlock(
#       (conv1): Conv1d(25, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(50, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(25, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(50, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(25, 50, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#     (2): TemporalBlock(
#       (conv1): Conv1d(50, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(75, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(50, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(75, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(50, 75, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#     (3): TemporalBlock(
#       (conv1): Conv1d(75, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(100, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(75, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(100, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(75, 100, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#   )
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %% [markdown]
# ## Model Training

# %%
# Model training function
def train(table, name, timeformat, model, batch_size, epochs, scaler_data, scaler_target, Min, Max, time_df_train, forecast_period):
    
    # Initialize training loss
    train_loss = []

    # Initialize best loss value
    best_Loss = np.inf

    for epoch in epochs:
        
        # Set the model to training mode
        model.train()
        
        # Initialize loss and total step
        running_loss = 0.0
        total_step = 0
        
        # Set initial start time
        start_time_ = str(time_df_train.index[0])
        
        # Set end time
        end_time_train = str(time_df_train.index[-1])
        
        # Use a while loop to call data 
        while start_time_ < end_time_train:
            
            # Set the time for loading data based on the batch size
            start_time_, end_time_, next_start_time_, index_next = update_time(time_df_train, start_time_, batch_size, forecast_period)
        
            # Load batch data
            data = data_load(table, name, start_time_, end_time_, timeformat)

            # Apply MinMax scaler
            data_scaled = scaler_data.fit_transform(data.iloc[:, :-1], Min.iloc[:,1:], Max.iloc[:,1:])
            target_scaled = scaler_target.fit_transform(data.iloc[:, -1:], Min.iloc[:,:1], Max.iloc[:,:1])
            
            # Set up the DataFrame
            data = pd.DataFrame(data_scaled)
            data['target'] = target_scaled
            
            # Move the target value up by one row to predict the target value of the next time step
            data['target'] = data['target'].shift(-forecast_period)
            
            # Remove the last row with NaN value
            data = data.dropna()
            
            # Print if the loaded data is empty
            if len(data) == 0:
                print("No data available.")
            
            # Input the data into the model when it accumulates to the batch size
            if len(data) == batch_size:
                
                # Check total batch count
                total_step += 1
                
                # Convert data to numpy arrays
                input_data = np.array(data.iloc[:, :-1])
                input_target = np.array(data.iloc[:, -1:])
                
                # Convert data to Tensor
                input_data = torch.tensor(input_data, dtype=torch.float32).to(device).float()
                input_target = torch.tensor(input_target, dtype=torch.float32).to(device).float()
                
                # Optimize the optimizer
                optimizer.zero_grad()
                
                # Input to the model
                outputs = model(input_data.unsqueeze(2))
        
                # Calculate loss
                loss = criterion(outputs, input_target)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                
                # Reset batch data
                data = []
                
            # Set the next start time
            start_time_ = unquote(next_start_time_)
            
            # Prevent fetching beyond the last time
            if index_next + batch_size + forecast_period >= len(time_df_train):
                break
            
        # Print training loss
        train_loss.append(running_loss / total_step)
        print(f'\ntrain loss: {np.mean(train_loss)}')
        
        # Save the model if it has the best loss
        if best_Loss > np.mean(train_loss):
            best_Loss = np.mean(train_loss)
            torch.save(model, f'./result/Air_Quality_New_Batch.pt')
            print('Model saved')
        epochs.set_postfix_str(f"epoch = {epoch}, best_Loss = {best_Loss}")
        
    return model

# %%
########################################### Training Parameter Settings ################################################
# Set the tag table name
table = 'india_air_quality'
# Set the tag names
name = quote(tags_, safe=":/")
# Set the time format 
timeformat = 'default'
# Set the data start time
start_time_train = '2016-07-01 10:00:00'
# Set the data end time
end_time_train = '2022-12-31 23:59:59'
# Set batch size
forecast_period = 1
batch_size = 64
# Set number of epochs
epochs = trange(100, desc='training')
# Set Min, Max value 
Min, Max = set_minmax_value(table, name, start_time_train, end_time_train)
# Set scalers
scaler_data = MinMaxScaler_custom()
scaler_target = MinMaxScaler_custom()
# Load training time list 
time_df_train = time_data_load(table, name, quote(start_time_train), quote(end_time_train), timeformat)
########################################### Proceed with training ################################################
train(table, name, timeformat, model, batch_size, epochs, scaler_data, scaler_target, Min, Max, time_df_train, forecast_period)
# Out:
# training:   0%|          | 0/100 [00:00<?, ?it/s]
# c:\Users\MACH-DE-28\anaconda3\envs\test\lib\site-packages\torch\autograd\graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# train loss: 0.45787239549786185
# Model saved
#
# train loss: 0.4518343241945474
# Model saved
#
# train loss: 0.4495749905630458
# Model saved
#
# train loss: 0.43626170052572555
# Model saved
#
# train loss: 0.4141738951550222
# Model saved
#
# train loss: 0.3950753597746916
# Model saved
#
# train loss: 0.37715698312999785
# Model saved
#
# train loss: 0.3640327755579338
# Model saved
#
# train loss: 0.35305445805140684
# Model saved
#
# train loss: 0.34362540586056245
# Model saved
#
# train loss: 0.3352687426804548
# Model saved
#
# train loss: 0.32799983233206226
# Model saved
#
# train loss: 0.321384320115606
# Model saved
#
# train loss: 0.31556709167575087
# Model saved
#
# train loss: 0.3100827470455554
# Model saved
#
# train loss: 0.304598097570375
# Model saved
#
# train loss: 0.2992225602963592
# Model saved
#
# train loss: 0.29421722970274433
# Model saved
#
# train loss: 0.2893885304952965
# Model saved
#
# train loss: 0.28454733963603485
# Model saved
#
# train loss: 0.2799341979852762
# Model saved
#
# train loss: 0.27547527823662193
# Model saved
#
# train loss: 0.2712348348064408
# Model saved
#
# train loss: 0.2671451211823955
# Model saved
#
# train loss: 0.2632625681825865
# Model saved
#
# train loss: 0.2595124320389267
# Model saved
#
# train loss: 0.25588546052373595
# Model saved
#
# train loss: 0.2523711883220662
# Model saved
#
# train loss: 0.2490519304759489
# Model saved
#
# train loss: 0.24574701221443884
# Model saved
#
# train loss: 0.24255229103896803
# Model saved
#
# train loss: 0.23958394817225695
# Model saved
#
# train loss: 0.2367543323775932
# Model saved
#
# train loss: 0.23392092286600893
# Model saved
#
# train loss: 0.23119754386101635
# Model saved
#
# train loss: 0.22851207568488585
# Model saved
#
# train loss: 0.2259118129430081
# Model saved
#
# train loss: 0.22333386909294722
# Model saved
#
# train loss: 0.2208952290570713
# Model saved
#
# train loss: 0.21848861285281415
# Model saved
#
# train loss: 0.21611174654397805
# Model saved
#
# train loss: 0.21381881575590156
# Model saved
#
# train loss: 0.21157924590062854
# Model saved
#
# train loss: 0.20943760654729388
# Model saved
#
# train loss: 0.20729847125439385
# Model saved
#
# train loss: 0.20520293433543904
# Model saved
#
# train loss: 0.20318168705117537
# Model saved
#
# train loss: 0.20117860993717337
# Model saved
#
# train loss: 0.1992187317129659
# Model saved
#
# train loss: 0.19731068178532787
# Model saved
#
# train loss: 0.19546986928845947
# Model saved
#
# train loss: 0.19365938873044303
# Model saved
#
# train loss: 0.19187368358837853
# Model saved
#
# train loss: 0.19014012287122423
# Model saved
#
# train loss: 0.18842890032897244
# Model saved
#
# train loss: 0.18679868194091487
# Model saved
#
# train loss: 0.18518284280660932
# Model saved
#
# train loss: 0.18360902441327506
# Model saved
#
# train loss: 0.18203583899643105
# Model saved
#
# train loss: 0.1805723858042062
# Model saved
#
# train loss: 0.17913403114072463
# Model saved
#
# train loss: 0.17772688558525737
# Model saved
#
# train loss: 0.17636164496705214
# Model saved
#
# train loss: 0.17503308854278035
# Model saved
#
# train loss: 0.17375245709710124
# Model saved
#
# train loss: 0.1724813642866896
# Model saved
#
# train loss: 0.17127815171477548
# Model saved
#
# train loss: 0.1700675669726086
# Model saved
#
# train loss: 0.16896637673747225
# Model saved
#
# train loss: 0.16783005005375107
# Model saved
#
# train loss: 0.16677485458320804
# Model saved
#
# train loss: 0.16569851257108673
# Model saved
#
# train loss: 0.16466310853705846
# Model saved
#
# train loss: 0.1636258676763126
# Model saved
#
# train loss: 0.16264422748624643
# Model saved
#
# train loss: 0.1616691208842593
# Model saved
#
# train loss: 0.16071906972443592
# Model saved
#
# train loss: 0.15980305456063887
# Model saved
#
# train loss: 0.15897502021782525
# Model saved
#
# train loss: 0.1580800980269554
# Model saved
#
# train loss: 0.1571941539049841
# Model saved
#
# train loss: 0.15632592842265933
# Model saved
#
# train loss: 0.1554670203480471
# Model saved
#
# train loss: 0.15469219899645045
# Model saved
#
# train loss: 0.15386658354940874
# Model saved
#
# train loss: 0.15305908185973033
# Model saved
#
# train loss: 0.15226446156842655
# Model saved
#
# train loss: 0.15154233459790892
# Model saved
#
# train loss: 0.15079462000775465
# Model saved
#
# train loss: 0.15011311812465894
# Model saved
#
# train loss: 0.1493770360363242
# Model saved
#
# train loss: 0.14866577723992452
# Model saved
#
# train loss: 0.1479526269383757
# Model saved
#
# train loss: 0.1472514524964507
# Model saved
#
# train loss: 0.14656605278696747
# Model saved
#
# train loss: 0.14592819061075998
# Model saved
#
# train loss: 0.1453602379318435
# Model saved
#
# train loss: 0.14472219716340612
# Model saved
#
# train loss: 0.14412081123458426
# Model saved
#
# train loss: 0.1435273796226246
# Model saved
# TCN(
#   (network): Sequential(
#     (0): TemporalBlock(
#       (conv1): Conv1d(20, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(25, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(20, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(25, 25, kernel_size=(3,), stride=(1,), padding=(2,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(20, 25, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#     (1): TemporalBlock(
#       (conv1): Conv1d(25, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(50, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(25, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(50, 50, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(25, 50, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#     (2): TemporalBlock(
#       (conv1): Conv1d(50, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(75, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(50, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(75, 75, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(50, 75, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#     (3): TemporalBlock(
#       (conv1): Conv1d(75, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.2, inplace=False)
#       (conv2): Conv1d(100, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.2, inplace=False)
#       (net): Sequential(
#         (0): Conv1d(75, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#         (1): ReLU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Conv1d(100, 100, kernel_size=(3,), stride=(1,), padding=(16,), dilation=(8,))
#         (4): ReLU()
#         (5): Dropout(p=0.2, inplace=False)
#       )
#       (downsample): Conv1d(75, 100, kernel_size=(1,), stride=(1,))
#       (relu): ReLU()
#     )
#   )
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %% [markdown]
# ## Model Testing

# %%
# Model testing function  
def test(table, name, timeformat, model, batch_size, scaler_data, scaler_target, Min, Max, time_df_test, forecast_period):
    with torch.no_grad():
                
        model.eval()
        
        # Initial settings 
        output_test = []
        output_target = []
            
        # Set the initial start time
        start_time_t = str(time_df_test.index[0])
        
        # Set the end time
        end_time_test = str(time_df_test.index[-1])
        
        # Use a while loop to call data 
        while start_time_t < end_time_test:
            
            # Set the time for loading data based on the batch size
            start_time_t, end_time_t, next_start_time_t, index_next_t = update_time(time_df_test, start_time_t, batch_size, forecast_period)
        
            # Load batch data
            data_t = data_load(table, name, start_time_t, end_time_t, timeformat)
            
            # Apply MinMax scaler
            data_scaled = scaler_data.fit_transform(data_t.iloc[:,:-1], Min.iloc[:,1:], Max.iloc[:,1:])
            target_scaled = scaler_target.fit_transform(data_t.iloc[:,-1:], Min.iloc[:,:1], Max.iloc[:,:1])
            
            # Set the DataFrame
            data_t = pd.DataFrame(data_scaled)
            data_t['target'] = target_scaled
            
            # Move the target value up by one row to predict the target value of the next time step
            data_t['target'] = data_t['target'].shift(-forecast_period)
            
            # Remove the last row with NaN value
            data_t = data_t.dropna()
            
            # Print if the loaded data is empty 
            if len(data_t) == 0:
                print("No data available.")
            
            # Move to the next batch if the data size matches the batch size
            if len(data_t) == batch_size:
                
                # Convert data to numpy arrays
                input_data_t = np.array(data_t.iloc[:, :-1])
                input_target_t = np.array(data_t.iloc[:, -1:])

                # Convert data to Tensor
                input_data_t = torch.tensor(input_data_t, dtype=torch.float32).to(device).float()
                input_target_t = torch.tensor(input_target_t, dtype=torch.float32).to(device).float()
                
                # Model input
                outputs_t = model(input_data_t.unsqueeze(2))
                
                output_test.append(outputs_t)
                output_target.append(input_target_t)
                
                # Reset the batch
                data_t = []

            # Set the next start time    
            start_time_t = unquote(next_start_time_t)
            
            # Prevent loading beyond the last time
            if index_next_t + batch_size + forecast_period >= len(time_df_test):
                break
        
        # Combine the tensors into one
        combined_tensor_target = torch.cat(output_target, dim=0)
        combined_tensor_pred = torch.cat(output_test, dim=0)

        # Use only the last values of the window
        last_values_target = combined_tensor_target[:, -1].cpu()
        last_values_pred = combined_tensor_pred.cpu()

        # Inverse transform using MinMaxScaler 
        real_values = scaler_target.inverse_transform(last_values_target.numpy().reshape(-1, 1))
        real_pred_values = scaler_target.inverse_transform(last_values_pred.numpy().reshape(-1, 1)) 
        
        return real_values, real_pred_values

# %%
########################################### Test Parameter Settings ################################################
# Load the best model
model_ = torch.load(f'./result/Air_Quality_New_Batch.pt')
# Set the start time for the test data
start_time_test = '2023-01-01 00:00:00'
# Set the end time for the test data
end_time_test = '2024-01-01 00:00:00'
# Load the test time list
time_df_test = time_data_load(table, name, quote(start_time_test), quote(end_time_test), timeformat)

######################################## Proceed with testing #############################################
real_values, real_pred_values = test(table, name, timeformat, model_, batch_size, scaler_data, scaler_target, Min, Max, time_df_test, forecast_period)

# %% [markdown]
# ## Model Performance Evaluation

# %%
# Calculate MSE
mse = mean_squared_error(real_values, real_pred_values)
print("Mean Squared Error:", mse)

# Calculate R² Score
r2 = r2_score(real_values, real_pred_values)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 55.481982606520994
# R² Score: 0.8338693347899135

# %%
# Compare the test results: Actual values vs Predicted values
plt.figure(figsize=(12, 6))
plt.plot(real_values, label='Actual', color='blue')
plt.plot(real_pred_values, label='Predicted', color='red', alpha=0.7)
plt.title('Actual vs Predicted')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.show()
